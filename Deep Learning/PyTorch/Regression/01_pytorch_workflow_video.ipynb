# %% [markdown]
# # PyTorch Workflow
#
# Let's explore an example PyTorch end-to-end workflow.
#
# Resources:
# * Book version - https://www.learnpytorch.io/01_pytorch_workflow/

# %%
what_were_covering = {1: "Data (prepare and load)",
                      2: "build model",
                      3: "fitting a model to the data",
                      4: "making predictions and evaluating a model (inference)",
                      5: "saving and loading a model",
                      6: "putting it all together"}
what_were_covering
# Out:
# {1: 'Data (prepare and load)',
#  2: 'build model',
#  3: 'fitting a model to the data',
#  4: 'making predictions and evaluating a model (inference)',
#  5: 'saving and loading a model',
#  6: 'putting it all together'}

# %%
import torch
if torch.cuda.is_available():
    print("GPU is available")
    print("GPU Device Name:", torch.cuda.get_device_name(0))
else:
    print("GPU not available, using CPU")
# Out:
# GPU is available
# GPU Device Name: NVIDIA GeForce RTX 3070 Ti

# %%
from torch import nn # nn contains all of PyTorch's building blocks for neural networks -https://pytorch.org/docs/stable/nn.html
import matplotlib.pyplot as plt

# %%
# Create *known* parameters
weight = 0.7
bias = 0.3

# Create data
start = 0
end = 1
step = 0.02
X = torch.arange(start, end, step).unsqueeze(dim=1)
y = weight * X + bias

X[:10], y[:10]
# Out:
# (tensor([[0.0000],
#          [0.0200],
#          [0.0400],
#          [0.0600],
#          [0.0800],
#          [0.1000],
#          [0.1200],
#          [0.1400],
#          [0.1600],
#          [0.1800]]),
#  tensor([[0.3000],
#          [0.3140],
#          [0.3280],
#          [0.3420],
#          [0.3560],
#          [0.3700],
#          [0.3840],
#          [0.3980],
#          [0.4120],
#          [0.4260]]))

# %%
# Create train/test split
train_split = int(0.8 * len(X)) # 80% of data used for training set, 20% for testing 
X_train, y_train = X[:train_split], y[:train_split]
X_test, y_test = X[train_split:], y[train_split:]

len(X_train), len(y_train), len(X_test), len(y_test)
# Out:
# (40, 40, 10, 10)

# %%
def plot_predictions(train_data=X_train, 
                     train_labels=y_train, 
                     test_data=X_test, 
                     test_labels=y_test, 
                     predictions=None):
  """
  Plots training data, test data and compares predictions.
  """
  plt.figure(figsize=(10, 7))

  # Plot training data in blue
  plt.scatter(train_data, train_labels, c="b", s=4, label="Training data")
  
  # Plot test data in green
  plt.scatter(test_data, test_labels, c="g", s=4, label="Testing data")

  if predictions is not None:
    # Plot the predictions in red (predictions were made on the test data)
    plt.scatter(test_data, predictions, c="r", s=4, label="Predictions")

  # Show the legend
  plt.legend(prop={"size": 14});

  plt.title("Graph of train, test and predictions dataset")

# %%
plot_predictions()

# %% [markdown]
# ## Build our first Pythorch model

# %% [markdown]
# Because we are building classes we uses OOP: https://realpython.com/python3-object-oriented-programming
#
# We use two main alogorithms for our model:
# - gradient descent - https://www.youtube.com/watch?v=IHZwWFHWa-w
# - backpropagation - https://www.youtube.com/watch?v=Ilg3gGewQ5U&t

# %%
# On définit un modèle de régression linéaire simple : y = w*x + b
class LinearRegressionModel(nn.Module):  
    # Presque tout dans PyTorch hérite de nn.Module → cela donne au modèle
    # des capacités comme la gestion automatique des paramètres et du GPU.

    def __init__(self):
        # On initialise la classe parente nn.Module
        super().__init__()

        # Définition des paramètres du modèle :
        #  - poids (w)
        #  - biais (b)
        # Ce sont les valeurs que le modèle va apprendre.

        # Poids initialisé aléatoirement (1 paramètre car x est 1D)
        self.weights = nn.Parameter(
            torch.randn(1, dtype=torch.float),  # valeur aléatoire
            requires_grad=True  # indique à PyTorch qu'on veut calculer le gradient de ce paramètre
        )

        # Biais initialisé aléatoirement (1 paramètre également)
        self.bias = nn.Parameter(
            torch.randn(1, dtype=torch.float),
            requires_grad=True
        )

    # La méthode forward définit le "calcul" du modèle :
    # c’est ici qu’on indique comment produire une sortie à partir d’une entrée.
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # Ici, la formule de la régression linéaire :
        # y = w * x + b
        return self.weights * x + self.bias

# %%
# Set manual seed since nn.Parameter are randomly initialzied
torch.manual_seed(42)

# Create an instance of the model (this is a subclass of nn.Module that contains nn.Parameter(s))
model_0 = LinearRegressionModel()

# Check the nn.Parameter(s) within the nn.Module subclass we created
list(model_0.parameters())
# Out:
# [Parameter containing:
#  tensor([0.3367], requires_grad=True),
#  Parameter containing:
#  tensor([0.1288], requires_grad=True)]

# %%
model_0.weights
# Out:
# Parameter containing:
# tensor([0.3367], requires_grad=True)

# %%
# List named parameters 
model_0.state_dict()
# Out:
# OrderedDict([('weights', tensor([0.3367])), ('bias', tensor([0.1288]))])

# %%
# Make predictions with model
# Deactivate gradient calculation
with torch.inference_mode(): 
    y_preds = model_0(X_test)

# Note: in older PyTorch code you might also see torch.no_grad()
# with torch.no_grad():
#   y_preds = model_0(X_test)

# %%
# Check the predictions
print(f"Number of testing samples: {len(X_test)}") 
print(f"Number of predictions made: {len(y_preds)}")
print(f"Predicted values:\n{y_preds}")
# Out:
# Number of testing samples: 10
# Number of predictions made: 10
# Predicted values:
# tensor([[0.3982],
#         [0.4049],
#         [0.4116],
#         [0.4184],
#         [0.4251],
#         [0.4318],
#         [0.4386],
#         [0.4453],
#         [0.4520],
#         [0.4588]])

# %%
plot_predictions(predictions=y_preds)

# %%
y_test - y_preds
# Out:
# tensor([[0.4618],
#         [0.4691],
#         [0.4764],
#         [0.4836],
#         [0.4909],
#         [0.4982],
#         [0.5054],
#         [0.5127],
#         [0.5200],
#         [0.5272]])

# %% [markdown]
# ### 3. Train model
#
# The whole idea of training is to move from a poor representation of a model to a better representation of the data.
#
# One way to measure how wrong are our data is to use the loss function.
#
# * Note: Loss function may also be called cost function or criterion in different areas.
#         For our we are going to refer to it as a loss function.
#
# * **Loss function:** A function to measure how wrong your model's predictions are to the ideal outputs, lower is better
# * **Optimizer:** Takes into account the loss of a model and adjusts the model's parameters (e.g weight and bias) to improve the loss function - https://pytorch.org/docs/stable/optim.html
#
# And specifically for PyTorch, we need:
# * A training loop
# * A testing loop

# %%
# Setup a loss function
loss_fn = nn.L1Loss()

# Setup an optimizer (stochastic gradient descent)
optimizer = torch.optim.SGD(params=model_0.parameters(),
                            lr=0.01) # The larger the learning rate is the larger the changes in the parameters is

# %% [markdown]
# For a regression problem, a loss function of `nn.L1Loss()` and an optimizer like `torch.optim.SGD()` will suffice whereas for a classification problem, you'll likely use a loss function of `nn.BCELoss()` (binary cross entropy loss).

# %% [markdown]
# ### Building a training loop (and a testing loop) in PyTorch
#
# A couple of things we need in a training loop:
# 0. Loop through the data
# 1. Forward pass (this involves moving through our model's `forward()`
#    functions) to make predictions on data - also called forward propagation
# 2. Calculate the loss (compare forward pass predictions to ground thruth label)
# 3. Optimizer zero grad
# 4. Loss backward - move backwards through the network to calculate the gradients
#    of each of the parameters of our model with respect to the loss (**backpropagation**)
# 5. Optimizer step - use the optimizer to adjust our model's parameters to try and improve
#    the loss (**gradient descent**)

# %%
with torch.inference_mode():
    list(model_0.parameters())

# %%
list(model_0.parameters())
# Out:
# [Parameter containing:
#  tensor([0.3367], requires_grad=True),
#  Parameter containing:
#  tensor([0.1288], requires_grad=True)]

# %% [markdown]
# ### 🧠 Gradient Descent
#
# ![Gradient Descent](images/Capture%20d’écran%20du%202025-11-03%2013-56-05.png)
#
# ---
#
# ### 📉 Loss
#
# ![Loss](images/Capture%20d’écran%20du%202025-11-03%2016-20-21.png)
#
# ---
#
# ### 🔁 Backpropagation
#
# ![Backpropagation](images/Capture%20d’écran%20du%202025-11-03%2016-21-54.png)

# %%
epochs = 185
list_loss = []
test_loss_ = []
train_loss = []
### Training
# 0. Loop through the data
for epoch in range(epochs):
    # Set the model to training mode
    model_0.train() # train mode in PyTorch sets all parameters that require gradients to require gradients
    dict_loss = {}
    # 1. Forward pass
    y_pred = model_0(X_train)

    # 2. Calculate the loss
    loss = loss_fn(y_pred, y_train)
    print(f"Loss: {loss}")

    # 3. Optimizer zero grad
    optimizer.zero_grad()

    # 4. Perform backpropagation on the loss with respect to the parameters of the model
    loss.backward()
    print(model_0.state_dict())
    # 5. Step the optimizer (perform gradient descent)
    optimizer.step() # by default how the optimizer changes will accumulate through the loop so... we have to zero them above in step 3 for the next iteration of the loop
    print(model_0.state_dict())

    if epoch == 165:
        optimizer.param_groups[0]['lr'] /=4

    # Testing
    model_0.eval() # turns off gradient tracking and other needless stettings for evaluation/testing (dropout/batch)
    with torch.inference_mode(): # Turns off gradient tracking and a couple of more things - https://twitter.com/PyTorch/status/1437838231505096708
        # 1. Do the forward pass 
        test_pred = model_0(X_test)

        # 2. Calculate the loss
        test_loss = loss_fn(test_pred, y_test)

    if epoch % 10 == 0:
        print(f"Epoch: {epoch} | Loss: {loss} | Test loss:{test_loss}")
    
    # Make a dictionnary of the values and add it to a list for each epoch
    dict_loss["epoch"] = epoch
    dict_loss["weights"] = round(model_0.weights[0].item(),4)
    dict_loss["bias"] = round(model_0.bias[0].item(),4)
    train_loss.append(round(loss.item(), 4))
    test_loss_.append(round(test_loss.item(),4))
    list_loss.append(dict_loss)

    print(f"=============================================================================================")
# Out:
# Loss: 0.31288138031959534
# OrderedDict({'weights': tensor([0.3367]), 'bias': tensor([0.1288])})
# OrderedDict({'weights': tensor([0.3406]), 'bias': tensor([0.1388])})
# Epoch: 0 | Loss: 0.31288138031959534 | Test loss:0.48106518387794495
# =============================================================================================
# Loss: 0.3013603389263153
# OrderedDict({'weights': tensor([0.3406]), 'bias': tensor([0.1388])})
# OrderedDict({'weights': tensor([0.3445]), 'bias': tensor([0.1488])})
# =============================================================================================
# Loss: 0.28983935713768005
# OrderedDict({'weights': tensor([0.3445]), 'bias': tensor([0.1488])})
# OrderedDict({'weights': tensor([0.3484]), 'bias': tensor([0.1588])})
# =============================================================================================
# Loss: 0.2783183455467224
# OrderedDict({'weights': tensor([0.3484]), 'bias': tensor([0.1588])})
# OrderedDict({'weights': tensor([0.3523]), 'bias': tensor([0.1688])})
# =============================================================================================
# Loss: 0.26679736375808716
# OrderedDict({'weights': tensor([0.3523]), 'bias': tensor([0.1688])})
# OrderedDict({'weights': tensor([0.3562]), 'bias': tensor([0.1788])})
# =============================================================================================
# Loss: 0.2552763521671295
# OrderedDict({'weights': tensor([0.3562]), 'bias': tensor([0.1788])})
# OrderedDict({'weights': tensor([0.3601]), 'bias': tensor([0.1888])})
# =============================================================================================
# Loss: 0.24375534057617188
# OrderedDict({'weights': tensor([0.3601]), 'bias': tensor([0.1888])})
# OrderedDict({'weights': tensor([0.3640]), 'bias': tensor([0.1988])})
# =============================================================================================
# Loss: 0.23223432898521423
# OrderedDict({'weights': tensor([0.3640]), 'bias': tensor([0.1988])})
# OrderedDict({'weights': tensor([0.3679]), 'bias': tensor([0.2088])})
# =============================================================================================
# Loss: 0.22071333229541779
# OrderedDict({'weights': tensor([0.3679]), 'bias': tensor([0.2088])})
# OrderedDict({'weights': tensor([0.3718]), 'bias': tensor([0.2188])})
# =============================================================================================
# Loss: 0.20919232070446014
# OrderedDict({'weights': tensor([0.3718]), 'bias': tensor([0.2188])})
# OrderedDict({'weights': tensor([0.3757]), 'bias': tensor([0.2288])})
# =============================================================================================
# Loss: 0.1976713240146637
# OrderedDict({'weights': tensor([0.3757]), 'bias': tensor([0.2288])})
# OrderedDict({'weights': tensor([0.3796]), 'bias': tensor([0.2388])})
# Epoch: 10 | Loss: 0.1976713240146637 | Test loss:0.3463551998138428
# =============================================================================================
# Loss: 0.18615034222602844
# OrderedDict({'weights': tensor([0.3796]), 'bias': tensor([0.2388])})
# OrderedDict({'weights': tensor([0.3835]), 'bias': tensor([0.2488])})
# =============================================================================================
# Loss: 0.1746293306350708
# OrderedDict({'weights': tensor([0.3835]), 'bias': tensor([0.2488])})
# OrderedDict({'weights': tensor([0.3874]), 'bias': tensor([0.2588])})
# =============================================================================================
# Loss: 0.16310831904411316
# OrderedDict({'weights': tensor([0.3874]), 'bias': tensor([0.2588])})
# OrderedDict({'weights': tensor([0.3913]), 'bias': tensor([0.2688])})
# =============================================================================================
# Loss: 0.1515873372554779
# OrderedDict({'weights': tensor([0.3913]), 'bias': tensor([0.2688])})
# OrderedDict({'weights': tensor([0.3952]), 'bias': tensor([0.2788])})
# =============================================================================================
# Loss: 0.14006635546684265
# OrderedDict({'weights': tensor([0.3952]), 'bias': tensor([0.2788])})
# OrderedDict({'weights': tensor([0.3991]), 'bias': tensor([0.2888])})
# =============================================================================================
# Loss: 0.1285453587770462
# OrderedDict({'weights': tensor([0.3991]), 'bias': tensor([0.2888])})
# OrderedDict({'weights': tensor([0.4030]), 'bias': tensor([0.2988])})
# =============================================================================================
# Loss: 0.11702437698841095
# OrderedDict({'weights': tensor([0.4030]), 'bias': tensor([0.2988])})
# OrderedDict({'weights': tensor([0.4069]), 'bias': tensor([0.3088])})
# =============================================================================================
# Loss: 0.1060912236571312
# OrderedDict({'weights': tensor([0.4069]), 'bias': tensor([0.3088])})
# OrderedDict({'weights': tensor([0.4108]), 'bias': tensor([0.3178])})
# =============================================================================================
# Loss: 0.09681284427642822
# OrderedDict({'weights': tensor([0.4108]), 'bias': tensor([0.3178])})
# OrderedDict({'weights': tensor([0.4146]), 'bias': tensor([0.3258])})
# =============================================================================================
# Loss: 0.08908725529909134
# OrderedDict({'weights': tensor([0.4146]), 'bias': tensor([0.3258])})
# OrderedDict({'weights': tensor([0.4184]), 'bias': tensor([0.3333])})
# Epoch: 20 | Loss: 0.08908725529909134 | Test loss:0.21729660034179688
# =============================================================================================
# Loss: 0.08227583020925522
# OrderedDict({'weights': tensor([0.4184]), 'bias': tensor([0.3333])})
# OrderedDict({'weights': tensor([0.4222]), 'bias': tensor([0.3403])})
# =============================================================================================
# Loss: 0.07638873159885406
# OrderedDict({'weights': tensor([0.4222]), 'bias': tensor([0.3403])})
# OrderedDict({'weights': tensor([0.4258]), 'bias': tensor([0.3463])})
# =============================================================================================
# Loss: 0.07160007208585739
# OrderedDict({'weights': tensor([0.4258]), 'bias': tensor([0.3463])})
# OrderedDict({'weights': tensor([0.4293]), 'bias': tensor([0.3518])})
# =============================================================================================
# Loss: 0.06747635453939438
# OrderedDict({'weights': tensor([0.4293]), 'bias': tensor([0.3518])})
# OrderedDict({'weights': tensor([0.4328]), 'bias': tensor([0.3568])})
# =============================================================================================
# Loss: 0.06395438313484192
# OrderedDict({'weights': tensor([0.4328]), 'bias': tensor([0.3568])})
# OrderedDict({'weights': tensor([0.4361]), 'bias': tensor([0.3613])})
# =============================================================================================
# Loss: 0.06097004935145378
# OrderedDict({'weights': tensor([0.4361]), 'bias': tensor([0.3613])})
# OrderedDict({'weights': tensor([0.4394]), 'bias': tensor([0.3653])})
# =============================================================================================
# Loss: 0.05845819041132927
# OrderedDict({'weights': tensor([0.4394]), 'bias': tensor([0.3653])})
# OrderedDict({'weights': tensor([0.4425]), 'bias': tensor([0.3688])})
# =============================================================================================
# Loss: 0.05635259300470352
# OrderedDict({'weights': tensor([0.4425]), 'bias': tensor([0.3688])})
# OrderedDict({'weights': tensor([0.4455]), 'bias': tensor([0.3718])})
# =============================================================================================
# Loss: 0.0545857772231102
# OrderedDict({'weights': tensor([0.4455]), 'bias': tensor([0.3718])})
# OrderedDict({'weights': tensor([0.4483]), 'bias': tensor([0.3743])})
# =============================================================================================
# Loss: 0.053148526698350906
# OrderedDict({'weights': tensor([0.4483]), 'bias': tensor([0.3743])})
# OrderedDict({'weights': tensor([0.4512]), 'bias': tensor([0.3768])})
# Epoch: 30 | Loss: 0.053148526698350906 | Test loss:0.14464017748832703
# =============================================================================================
# Loss: 0.05181945487856865
# OrderedDict({'weights': tensor([0.4512]), 'bias': tensor([0.3768])})
# OrderedDict({'weights': tensor([0.4539]), 'bias': tensor([0.3788])})
# =============================================================================================
# Loss: 0.05069301277399063
# OrderedDict({'weights': tensor([0.4539]), 'bias': tensor([0.3788])})
# OrderedDict({'weights': tensor([0.4564]), 'bias': tensor([0.3803])})
# =============================================================================================
# Loss: 0.0498228520154953
# OrderedDict({'weights': tensor([0.4564]), 'bias': tensor([0.3803])})
# OrderedDict({'weights': tensor([0.4590]), 'bias': tensor([0.3818])})
# =============================================================================================
# Loss: 0.04895269125699997
# OrderedDict({'weights': tensor([0.4590]), 'bias': tensor([0.3818])})
# OrderedDict({'weights': tensor([0.4615]), 'bias': tensor([0.3833])})
# =============================================================================================
# Loss: 0.04819351062178612
# OrderedDict({'weights': tensor([0.4615]), 'bias': tensor([0.3833])})
# OrderedDict({'weights': tensor([0.4639]), 'bias': tensor([0.3843])})
# =============================================================================================
# Loss: 0.047531817108392715
# OrderedDict({'weights': tensor([0.4639]), 'bias': tensor([0.3843])})
# OrderedDict({'weights': tensor([0.4662]), 'bias': tensor([0.3853])})
# =============================================================================================
# Loss: 0.04692792519927025
# OrderedDict({'weights': tensor([0.4662]), 'bias': tensor([0.3853])})
# OrderedDict({'weights': tensor([0.4684]), 'bias': tensor([0.3858])})
# =============================================================================================
# Loss: 0.04642331600189209
# OrderedDict({'weights': tensor([0.4684]), 'bias': tensor([0.3858])})
# OrderedDict({'weights': tensor([0.4706]), 'bias': tensor([0.3863])})
# =============================================================================================
# Loss: 0.04591871052980423
# OrderedDict({'weights': tensor([0.4706]), 'bias': tensor([0.3863])})
# OrderedDict({'weights': tensor([0.4728]), 'bias': tensor([0.3868])})
# =============================================================================================
# Loss: 0.04543796554207802
# OrderedDict({'weights': tensor([0.4728]), 'bias': tensor([0.3868])})
# OrderedDict({'weights': tensor([0.4748]), 'bias': tensor([0.3868])})
# Epoch: 40 | Loss: 0.04543796554207802 | Test loss:0.11360953003168106
# =============================================================================================
# Loss: 0.04503796249628067
# OrderedDict({'weights': tensor([0.4748]), 'bias': tensor([0.3868])})
# OrderedDict({'weights': tensor([0.4768]), 'bias': tensor([0.3868])})
# =============================================================================================
# Loss: 0.04463795945048332
# OrderedDict({'weights': tensor([0.4768]), 'bias': tensor([0.3868])})
# OrderedDict({'weights': tensor([0.4788]), 'bias': tensor([0.3868])})
# =============================================================================================
# Loss: 0.04423796385526657
# OrderedDict({'weights': tensor([0.4788]), 'bias': tensor([0.3868])})
# OrderedDict({'weights': tensor([0.4808]), 'bias': tensor([0.3868])})
# =============================================================================================
# Loss: 0.04383796453475952
# OrderedDict({'weights': tensor([0.4808]), 'bias': tensor([0.3868])})
# OrderedDict({'weights': tensor([0.4828]), 'bias': tensor([0.3868])})
# =============================================================================================
# Loss: 0.04343796148896217
# OrderedDict({'weights': tensor([0.4828]), 'bias': tensor([0.3868])})
# OrderedDict({'weights': tensor([0.4848]), 'bias': tensor([0.3868])})
# =============================================================================================
# Loss: 0.043074630200862885
# OrderedDict({'weights': tensor([0.4848]), 'bias': tensor([0.3868])})
# OrderedDict({'weights': tensor([0.4866]), 'bias': tensor([0.3863])})
# =============================================================================================
# Loss: 0.04272563382983208
# OrderedDict({'weights': tensor([0.4866]), 'bias': tensor([0.3863])})
# OrderedDict({'weights': tensor([0.4884]), 'bias': tensor([0.3858])})
# =============================================================================================
# Loss: 0.04237663000822067
# OrderedDict({'weights': tensor([0.4884]), 'bias': tensor([0.3858])})
# OrderedDict({'weights': tensor([0.4902]), 'bias': tensor([0.3853])})
# =============================================================================================
# Loss: 0.04202762991189957
# OrderedDict({'weights': tensor([0.4902]), 'bias': tensor([0.3853])})
# OrderedDict({'weights': tensor([0.4920]), 'bias': tensor([0.3848])})
# =============================================================================================
# Loss: 0.04167863354086876
# OrderedDict({'weights': tensor([0.4920]), 'bias': tensor([0.3848])})
# OrderedDict({'weights': tensor([0.4938]), 'bias': tensor([0.3843])})
# Epoch: 50 | Loss: 0.04167863354086876 | Test loss:0.09919948130846024
# =============================================================================================
# Loss: 0.04132963344454765
# OrderedDict({'weights': tensor([0.4938]), 'bias': tensor([0.3843])})
# OrderedDict({'weights': tensor([0.4956]), 'bias': tensor([0.3838])})
# =============================================================================================
# Loss: 0.04098063334822655
# OrderedDict({'weights': tensor([0.4956]), 'bias': tensor([0.3838])})
# OrderedDict({'weights': tensor([0.4974]), 'bias': tensor([0.3833])})
# =============================================================================================
# Loss: 0.04063162952661514
# OrderedDict({'weights': tensor([0.4974]), 'bias': tensor([0.3833])})
# OrderedDict({'weights': tensor([0.4992]), 'bias': tensor([0.3828])})
# =============================================================================================
# Loss: 0.040282636880874634
# OrderedDict({'weights': tensor([0.4992]), 'bias': tensor([0.3828])})
# OrderedDict({'weights': tensor([0.5010]), 'bias': tensor([0.3823])})
# =============================================================================================
# Loss: 0.039933640509843826
# OrderedDict({'weights': tensor([0.5010]), 'bias': tensor([0.3823])})
# OrderedDict({'weights': tensor([0.5028]), 'bias': tensor([0.3818])})
# =============================================================================================
# Loss: 0.03958464413881302
# OrderedDict({'weights': tensor([0.5028]), 'bias': tensor([0.3818])})
# OrderedDict({'weights': tensor([0.5046]), 'bias': tensor([0.3813])})
# =============================================================================================
# Loss: 0.03923564404249191
# OrderedDict({'weights': tensor([0.5046]), 'bias': tensor([0.3813])})
# OrderedDict({'weights': tensor([0.5064]), 'bias': tensor([0.3808])})
# =============================================================================================
# Loss: 0.03888664394617081
# OrderedDict({'weights': tensor([0.5064]), 'bias': tensor([0.3808])})
# OrderedDict({'weights': tensor([0.5082]), 'bias': tensor([0.3803])})
# =============================================================================================
# Loss: 0.0385376438498497
# OrderedDict({'weights': tensor([0.5082]), 'bias': tensor([0.3803])})
# OrderedDict({'weights': tensor([0.5100]), 'bias': tensor([0.3798])})
# =============================================================================================
# Loss: 0.03818932920694351
# OrderedDict({'weights': tensor([0.5100]), 'bias': tensor([0.3798])})
# OrderedDict({'weights': tensor([0.5116]), 'bias': tensor([0.3788])})
# Epoch: 60 | Loss: 0.03818932920694351 | Test loss:0.08886633068323135
# =============================================================================================
# Loss: 0.03785243630409241
# OrderedDict({'weights': tensor([0.5116]), 'bias': tensor([0.3788])})
# OrderedDict({'weights': tensor([0.5134]), 'bias': tensor([0.3783])})
# =============================================================================================
# Loss: 0.0375034399330616
# OrderedDict({'weights': tensor([0.5134]), 'bias': tensor([0.3783])})
# OrderedDict({'weights': tensor([0.5152]), 'bias': tensor([0.3778])})
# =============================================================================================
# Loss: 0.037164121866226196
# OrderedDict({'weights': tensor([0.5152]), 'bias': tensor([0.3778])})
# OrderedDict({'weights': tensor([0.5168]), 'bias': tensor([0.3768])})
# =============================================================================================
# Loss: 0.03681822493672371
# OrderedDict({'weights': tensor([0.5168]), 'bias': tensor([0.3768])})
# OrderedDict({'weights': tensor([0.5186]), 'bias': tensor([0.3763])})
# =============================================================================================
# Loss: 0.03647511452436447
# OrderedDict({'weights': tensor([0.5186]), 'bias': tensor([0.3763])})
# OrderedDict({'weights': tensor([0.5202]), 'bias': tensor([0.3753])})
# =============================================================================================
# Loss: 0.03613303601741791
# OrderedDict({'weights': tensor([0.5202]), 'bias': tensor([0.3753])})
# OrderedDict({'weights': tensor([0.5220]), 'bias': tensor([0.3748])})
# =============================================================================================
# Loss: 0.03578609973192215
# OrderedDict({'weights': tensor([0.5220]), 'bias': tensor([0.3748])})
# OrderedDict({'weights': tensor([0.5236]), 'bias': tensor([0.3738])})
# =============================================================================================
# Loss: 0.03544783592224121
# OrderedDict({'weights': tensor([0.5236]), 'bias': tensor([0.3738])})
# OrderedDict({'weights': tensor([0.5254]), 'bias': tensor([0.3733])})
# =============================================================================================
# Loss: 0.035098835825920105
# OrderedDict({'weights': tensor([0.5254]), 'bias': tensor([0.3733])})
# OrderedDict({'weights': tensor([0.5272]), 'bias': tensor([0.3728])})
# =============================================================================================
# Loss: 0.03476089984178543
# OrderedDict({'weights': tensor([0.5272]), 'bias': tensor([0.3728])})
# OrderedDict({'weights': tensor([0.5288]), 'bias': tensor([0.3718])})
# Epoch: 70 | Loss: 0.03476089984178543 | Test loss:0.0805937647819519
# =============================================================================================
# Loss: 0.03441363573074341
# OrderedDict({'weights': tensor([0.5288]), 'bias': tensor([0.3718])})
# OrderedDict({'weights': tensor([0.5306]), 'bias': tensor([0.3713])})
# =============================================================================================
# Loss: 0.03407188132405281
# OrderedDict({'weights': tensor([0.5306]), 'bias': tensor([0.3713])})
# OrderedDict({'weights': tensor([0.5322]), 'bias': tensor([0.3703])})
# =============================================================================================
# Loss: 0.03372843936085701
# OrderedDict({'weights': tensor([0.5322]), 'bias': tensor([0.3703])})
# OrderedDict({'weights': tensor([0.5340]), 'bias': tensor([0.3698])})
# =============================================================================================
# Loss: 0.03338287025690079
# OrderedDict({'weights': tensor([0.5340]), 'bias': tensor([0.3698])})
# OrderedDict({'weights': tensor([0.5355]), 'bias': tensor([0.3688])})
# =============================================================================================
# Loss: 0.033043231815099716
# OrderedDict({'weights': tensor([0.5355]), 'bias': tensor([0.3688])})
# OrderedDict({'weights': tensor([0.5373]), 'bias': tensor([0.3683])})
# =============================================================================================
# Loss: 0.03269423171877861
# OrderedDict({'weights': tensor([0.5373]), 'bias': tensor([0.3683])})
# OrderedDict({'weights': tensor([0.5391]), 'bias': tensor([0.3678])})
# =============================================================================================
# Loss: 0.032357655465602875
# OrderedDict({'weights': tensor([0.5391]), 'bias': tensor([0.3678])})
# OrderedDict({'weights': tensor([0.5407]), 'bias': tensor([0.3668])})
# =============================================================================================
# Loss: 0.03200903534889221
# OrderedDict({'weights': tensor([0.5407]), 'bias': tensor([0.3668])})
# OrderedDict({'weights': tensor([0.5425]), 'bias': tensor([0.3663])})
# =============================================================================================
# Loss: 0.03166864812374115
# OrderedDict({'weights': tensor([0.5425]), 'bias': tensor([0.3663])})
# OrderedDict({'weights': tensor([0.5441]), 'bias': tensor([0.3653])})
# =============================================================================================
# Loss: 0.03132382780313492
# OrderedDict({'weights': tensor([0.5441]), 'bias': tensor([0.3653])})
# OrderedDict({'weights': tensor([0.5459]), 'bias': tensor([0.3648])})
# Epoch: 80 | Loss: 0.03132382780313492 | Test loss:0.07232122868299484
# =============================================================================================
# Loss: 0.030979642644524574
# OrderedDict({'weights': tensor([0.5459]), 'bias': tensor([0.3648])})
# OrderedDict({'weights': tensor([0.5475]), 'bias': tensor([0.3638])})
# =============================================================================================
# Loss: 0.030638623982667923
# OrderedDict({'weights': tensor([0.5475]), 'bias': tensor([0.3638])})
# OrderedDict({'weights': tensor([0.5493]), 'bias': tensor([0.3633])})
# =============================================================================================
# Loss: 0.0302906334400177
# OrderedDict({'weights': tensor([0.5493]), 'bias': tensor([0.3633])})
# OrderedDict({'weights': tensor([0.5509]), 'bias': tensor([0.3623])})
# =============================================================================================
# Loss: 0.029953425750136375
# OrderedDict({'weights': tensor([0.5509]), 'bias': tensor([0.3623])})
# OrderedDict({'weights': tensor([0.5527]), 'bias': tensor([0.3618])})
# =============================================================================================
# Loss: 0.02960442565381527
# OrderedDict({'weights': tensor([0.5527]), 'bias': tensor([0.3618])})
# OrderedDict({'weights': tensor([0.5545]), 'bias': tensor([0.3613])})
# =============================================================================================
# Loss: 0.029265418648719788
# OrderedDict({'weights': tensor([0.5545]), 'bias': tensor([0.3613])})
# OrderedDict({'weights': tensor([0.5561]), 'bias': tensor([0.3603])})
# =============================================================================================
# Loss: 0.028919223695993423
# OrderedDict({'weights': tensor([0.5561]), 'bias': tensor([0.3603])})
# OrderedDict({'weights': tensor([0.5579]), 'bias': tensor([0.3598])})
# =============================================================================================
# Loss: 0.028576409444212914
# OrderedDict({'weights': tensor([0.5579]), 'bias': tensor([0.3598])})
# OrderedDict({'weights': tensor([0.5595]), 'bias': tensor([0.3588])})
# =============================================================================================
# Loss: 0.028234025463461876
# OrderedDict({'weights': tensor([0.5595]), 'bias': tensor([0.3588])})
# OrderedDict({'weights': tensor([0.5613]), 'bias': tensor([0.3583])})
# =============================================================================================
# Loss: 0.02788739837706089
# OrderedDict({'weights': tensor([0.5613]), 'bias': tensor([0.3583])})
# OrderedDict({'weights': tensor([0.5629]), 'bias': tensor([0.3573])})
# Epoch: 90 | Loss: 0.02788739837706089 | Test loss:0.06473556160926819
# =============================================================================================
# Loss: 0.02754882536828518
# OrderedDict({'weights': tensor([0.5629]), 'bias': tensor([0.3573])})
# OrderedDict({'weights': tensor([0.5647]), 'bias': tensor([0.3568])})
# =============================================================================================
# Loss: 0.027199819684028625
# OrderedDict({'weights': tensor([0.5647]), 'bias': tensor([0.3568])})
# OrderedDict({'weights': tensor([0.5665]), 'bias': tensor([0.3563])})
# =============================================================================================
# Loss: 0.026862185448408127
# OrderedDict({'weights': tensor([0.5665]), 'bias': tensor([0.3563])})
# OrderedDict({'weights': tensor([0.5681]), 'bias': tensor([0.3553])})
# =============================================================================================
# Loss: 0.02651461586356163
# OrderedDict({'weights': tensor([0.5681]), 'bias': tensor([0.3553])})
# OrderedDict({'weights': tensor([0.5699]), 'bias': tensor([0.3548])})
# =============================================================================================
# Loss: 0.026173178106546402
# OrderedDict({'weights': tensor([0.5699]), 'bias': tensor([0.3548])})
# OrderedDict({'weights': tensor([0.5715]), 'bias': tensor([0.3538])})
# =============================================================================================
# Loss: 0.025829419493675232
# OrderedDict({'weights': tensor([0.5715]), 'bias': tensor([0.3538])})
# OrderedDict({'weights': tensor([0.5733]), 'bias': tensor([0.3533])})
# =============================================================================================
# Loss: 0.02548416517674923
# OrderedDict({'weights': tensor([0.5733]), 'bias': tensor([0.3533])})
# OrderedDict({'weights': tensor([0.5748]), 'bias': tensor([0.3523])})
# =============================================================================================
# Loss: 0.025144213810563087
# OrderedDict({'weights': tensor([0.5748]), 'bias': tensor([0.3523])})
# OrderedDict({'weights': tensor([0.5766]), 'bias': tensor([0.3518])})
# =============================================================================================
# Loss: 0.02479521557688713
# OrderedDict({'weights': tensor([0.5766]), 'bias': tensor([0.3518])})
# OrderedDict({'weights': tensor([0.5784]), 'bias': tensor([0.3513])})
# =============================================================================================
# Loss: 0.024458957836031914
# OrderedDict({'weights': tensor([0.5784]), 'bias': tensor([0.3513])})
# OrderedDict({'weights': tensor([0.5800]), 'bias': tensor([0.3503])})
# Epoch: 100 | Loss: 0.024458957836031914 | Test loss:0.05646304413676262
# =============================================================================================
# Loss: 0.024110013619065285
# OrderedDict({'weights': tensor([0.5800]), 'bias': tensor([0.3503])})
# OrderedDict({'weights': tensor([0.5818]), 'bias': tensor([0.3498])})
# =============================================================================================
# Loss: 0.02376994863152504
# OrderedDict({'weights': tensor([0.5818]), 'bias': tensor([0.3498])})
# OrderedDict({'weights': tensor([0.5834]), 'bias': tensor([0.3488])})
# =============================================================================================
# Loss: 0.02342480979859829
# OrderedDict({'weights': tensor([0.5834]), 'bias': tensor([0.3488])})
# OrderedDict({'weights': tensor([0.5852]), 'bias': tensor([0.3483])})
# =============================================================================================
# Loss: 0.023080935701727867
# OrderedDict({'weights': tensor([0.5852]), 'bias': tensor([0.3483])})
# OrderedDict({'weights': tensor([0.5868]), 'bias': tensor([0.3473])})
# =============================================================================================
# Loss: 0.022739607840776443
# OrderedDict({'weights': tensor([0.5868]), 'bias': tensor([0.3473])})
# OrderedDict({'weights': tensor([0.5886]), 'bias': tensor([0.3468])})
# =============================================================================================
# Loss: 0.022391926497220993
# OrderedDict({'weights': tensor([0.5886]), 'bias': tensor([0.3468])})
# OrderedDict({'weights': tensor([0.5902]), 'bias': tensor([0.3458])})
# =============================================================================================
# Loss: 0.022054409608244896
# OrderedDict({'weights': tensor([0.5902]), 'bias': tensor([0.3458])})
# OrderedDict({'weights': tensor([0.5920]), 'bias': tensor([0.3453])})
# =============================================================================================
# Loss: 0.02170540764927864
# OrderedDict({'weights': tensor([0.5920]), 'bias': tensor([0.3453])})
# OrderedDict({'weights': tensor([0.5938]), 'bias': tensor([0.3448])})
# =============================================================================================
# Loss: 0.021366719156503677
# OrderedDict({'weights': tensor([0.5938]), 'bias': tensor([0.3448])})
# OrderedDict({'weights': tensor([0.5954]), 'bias': tensor([0.3438])})
# =============================================================================================
# Loss: 0.021020207554101944
# OrderedDict({'weights': tensor([0.5954]), 'bias': tensor([0.3438])})
# OrderedDict({'weights': tensor([0.5972]), 'bias': tensor([0.3433])})
# Epoch: 110 | Loss: 0.021020207554101944 | Test loss:0.04819049686193466
# =============================================================================================
# Loss: 0.020677709951996803
# OrderedDict({'weights': tensor([0.5972]), 'bias': tensor([0.3433])})
# OrderedDict({'weights': tensor([0.5988]), 'bias': tensor([0.3423])})
# =============================================================================================
# Loss: 0.02033500373363495
# OrderedDict({'weights': tensor([0.5988]), 'bias': tensor([0.3423])})
# OrderedDict({'weights': tensor([0.6006]), 'bias': tensor([0.3418])})
# =============================================================================================
# Loss: 0.01998869702219963
# OrderedDict({'weights': tensor([0.6006]), 'bias': tensor([0.3418])})
# OrderedDict({'weights': tensor([0.6022]), 'bias': tensor([0.3408])})
# =============================================================================================
# Loss: 0.019649803638458252
# OrderedDict({'weights': tensor([0.6022]), 'bias': tensor([0.3408])})
# OrderedDict({'weights': tensor([0.6040]), 'bias': tensor([0.3403])})
# =============================================================================================
# Loss: 0.019300809130072594
# OrderedDict({'weights': tensor([0.6040]), 'bias': tensor([0.3403])})
# OrderedDict({'weights': tensor([0.6058]), 'bias': tensor([0.3398])})
# =============================================================================================
# Loss: 0.018963487818837166
# OrderedDict({'weights': tensor([0.6058]), 'bias': tensor([0.3398])})
# OrderedDict({'weights': tensor([0.6074]), 'bias': tensor([0.3388])})
# =============================================================================================
# Loss: 0.01861560344696045
# OrderedDict({'weights': tensor([0.6074]), 'bias': tensor([0.3388])})
# OrderedDict({'weights': tensor([0.6092]), 'bias': tensor([0.3383])})
# =============================================================================================
# Loss: 0.018274478614330292
# OrderedDict({'weights': tensor([0.6092]), 'bias': tensor([0.3383])})
# OrderedDict({'weights': tensor([0.6108]), 'bias': tensor([0.3373])})
# =============================================================================================
# Loss: 0.017930403351783752
# OrderedDict({'weights': tensor([0.6108]), 'bias': tensor([0.3373])})
# OrderedDict({'weights': tensor([0.6126]), 'bias': tensor([0.3368])})
# =============================================================================================
# Loss: 0.01758546568453312
# OrderedDict({'weights': tensor([0.6126]), 'bias': tensor([0.3368])})
# OrderedDict({'weights': tensor([0.6141]), 'bias': tensor([0.3358])})
# Epoch: 120 | Loss: 0.01758546568453312 | Test loss:0.04060482233762741
# =============================================================================================
# Loss: 0.017245199531316757
# OrderedDict({'weights': tensor([0.6141]), 'bias': tensor([0.3358])})
# OrderedDict({'weights': tensor([0.6159]), 'bias': tensor([0.3353])})
# =============================================================================================
# Loss: 0.016896454617381096
# OrderedDict({'weights': tensor([0.6159]), 'bias': tensor([0.3353])})
# OrderedDict({'weights': tensor([0.6175]), 'bias': tensor([0.3343])})
# =============================================================================================
# Loss: 0.01656000316143036
# OrderedDict({'weights': tensor([0.6175]), 'bias': tensor([0.3343])})
# OrderedDict({'weights': tensor([0.6193]), 'bias': tensor([0.3338])})
# =============================================================================================
# Loss: 0.016210997477173805
# OrderedDict({'weights': tensor([0.6193]), 'bias': tensor([0.3338])})
# OrderedDict({'weights': tensor([0.6211]), 'bias': tensor([0.3333])})
# =============================================================================================
# Loss: 0.01587124727666378
# OrderedDict({'weights': tensor([0.6211]), 'bias': tensor([0.3333])})
# OrderedDict({'weights': tensor([0.6227]), 'bias': tensor([0.3323])})
# =============================================================================================
# Loss: 0.015525798313319683
# OrderedDict({'weights': tensor([0.6227]), 'bias': tensor([0.3323])})
# OrderedDict({'weights': tensor([0.6245]), 'bias': tensor([0.3318])})
# =============================================================================================
# Loss: 0.015182236209511757
# OrderedDict({'weights': tensor([0.6245]), 'bias': tensor([0.3318])})
# OrderedDict({'weights': tensor([0.6261]), 'bias': tensor([0.3308])})
# =============================================================================================
# Loss: 0.014840595424175262
# OrderedDict({'weights': tensor([0.6261]), 'bias': tensor([0.3308])})
# OrderedDict({'weights': tensor([0.6279]), 'bias': tensor([0.3303])})
# =============================================================================================
# Loss: 0.01449323259294033
# OrderedDict({'weights': tensor([0.6279]), 'bias': tensor([0.3303])})
# OrderedDict({'weights': tensor([0.6295]), 'bias': tensor([0.3293])})
# =============================================================================================
# Loss: 0.014155393466353416
# OrderedDict({'weights': tensor([0.6295]), 'bias': tensor([0.3293])})
# OrderedDict({'weights': tensor([0.6313]), 'bias': tensor([0.3288])})
# Epoch: 130 | Loss: 0.014155393466353416 | Test loss:0.03233227878808975
# =============================================================================================
# Loss: 0.013806397095322609
# OrderedDict({'weights': tensor([0.6313]), 'bias': tensor([0.3288])})
# OrderedDict({'weights': tensor([0.6331]), 'bias': tensor([0.3283])})
# =============================================================================================
# Loss: 0.013468016870319843
# OrderedDict({'weights': tensor([0.6331]), 'bias': tensor([0.3283])})
# OrderedDict({'weights': tensor([0.6347]), 'bias': tensor([0.3273])})
# =============================================================================================
# Loss: 0.013121193274855614
# OrderedDict({'weights': tensor([0.6347]), 'bias': tensor([0.3273])})
# OrderedDict({'weights': tensor([0.6365]), 'bias': tensor([0.3268])})
# =============================================================================================
# Loss: 0.01277900766581297
# OrderedDict({'weights': tensor([0.6365]), 'bias': tensor([0.3268])})
# OrderedDict({'weights': tensor([0.6381]), 'bias': tensor([0.3258])})
# =============================================================================================
# Loss: 0.012435992248356342
# OrderedDict({'weights': tensor([0.6381]), 'bias': tensor([0.3258])})
# OrderedDict({'weights': tensor([0.6399]), 'bias': tensor([0.3253])})
# =============================================================================================
# Loss: 0.01208999752998352
# OrderedDict({'weights': tensor([0.6399]), 'bias': tensor([0.3253])})
# OrderedDict({'weights': tensor([0.6415]), 'bias': tensor([0.3243])})
# =============================================================================================
# Loss: 0.011750795878469944
# OrderedDict({'weights': tensor([0.6415]), 'bias': tensor([0.3243])})
# OrderedDict({'weights': tensor([0.6433]), 'bias': tensor([0.3238])})
# =============================================================================================
# Loss: 0.011401787400245667
# OrderedDict({'weights': tensor([0.6433]), 'bias': tensor([0.3238])})
# OrderedDict({'weights': tensor([0.6451]), 'bias': tensor([0.3233])})
# =============================================================================================
# Loss: 0.011064787395298481
# OrderedDict({'weights': tensor([0.6451]), 'bias': tensor([0.3233])})
# OrderedDict({'weights': tensor([0.6467]), 'bias': tensor([0.3223])})
# =============================================================================================
# Loss: 0.010716589167714119
# OrderedDict({'weights': tensor([0.6467]), 'bias': tensor([0.3223])})
# OrderedDict({'weights': tensor([0.6485]), 'bias': tensor([0.3218])})
# Epoch: 140 | Loss: 0.010716589167714119 | Test loss:0.024059748277068138
# =============================================================================================
# Loss: 0.010375778190791607
# OrderedDict({'weights': tensor([0.6485]), 'bias': tensor([0.3218])})
# OrderedDict({'weights': tensor([0.6501]), 'bias': tensor([0.3208])})
# =============================================================================================
# Loss: 0.010031387209892273
# OrderedDict({'weights': tensor([0.6501]), 'bias': tensor([0.3208])})
# OrderedDict({'weights': tensor([0.6519]), 'bias': tensor([0.3203])})
# =============================================================================================
# Loss: 0.009686763398349285
# OrderedDict({'weights': tensor([0.6519]), 'bias': tensor([0.3203])})
# OrderedDict({'weights': tensor([0.6534]), 'bias': tensor([0.3193])})
# =============================================================================================
# Loss: 0.009346187114715576
# OrderedDict({'weights': tensor([0.6534]), 'bias': tensor([0.3193])})
# OrderedDict({'weights': tensor([0.6552]), 'bias': tensor([0.3188])})
# =============================================================================================
# Loss: 0.008997755125164986
# OrderedDict({'weights': tensor([0.6552]), 'bias': tensor([0.3188])})
# OrderedDict({'weights': tensor([0.6568]), 'bias': tensor([0.3178])})
# =============================================================================================
# Loss: 0.008660981431603432
# OrderedDict({'weights': tensor([0.6568]), 'bias': tensor([0.3178])})
# OrderedDict({'weights': tensor([0.6586]), 'bias': tensor([0.3173])})
# =============================================================================================
# Loss: 0.008311985060572624
# OrderedDict({'weights': tensor([0.6586]), 'bias': tensor([0.3173])})
# OrderedDict({'weights': tensor([0.6604]), 'bias': tensor([0.3168])})
# =============================================================================================
# Loss: 0.007972544990479946
# OrderedDict({'weights': tensor([0.6604]), 'bias': tensor([0.3168])})
# OrderedDict({'weights': tensor([0.6620]), 'bias': tensor([0.3158])})
# =============================================================================================
# Loss: 0.007626785431057215
# OrderedDict({'weights': tensor([0.6620]), 'bias': tensor([0.3158])})
# OrderedDict({'weights': tensor([0.6638]), 'bias': tensor([0.3153])})
# =============================================================================================
# Loss: 0.0072835334576666355
# OrderedDict({'weights': tensor([0.6638]), 'bias': tensor([0.3153])})
# OrderedDict({'weights': tensor([0.6654]), 'bias': tensor([0.3143])})
# Epoch: 150 | Loss: 0.0072835334576666355 | Test loss:0.016474086791276932
# =============================================================================================
# Loss: 0.006941580679267645
# OrderedDict({'weights': tensor([0.6654]), 'bias': tensor([0.3143])})
# OrderedDict({'weights': tensor([0.6672]), 'bias': tensor([0.3138])})
# =============================================================================================
# Loss: 0.006594526115804911
# OrderedDict({'weights': tensor([0.6672]), 'bias': tensor([0.3138])})
# OrderedDict({'weights': tensor([0.6688]), 'bias': tensor([0.3128])})
# =============================================================================================
# Loss: 0.006256377790123224
# OrderedDict({'weights': tensor([0.6688]), 'bias': tensor([0.3128])})
# OrderedDict({'weights': tensor([0.6706]), 'bias': tensor([0.3123])})
# =============================================================================================
# Loss: 0.005907376762479544
# OrderedDict({'weights': tensor([0.6706]), 'bias': tensor([0.3123])})
# OrderedDict({'weights': tensor([0.6724]), 'bias': tensor([0.3118])})
# =============================================================================================
# Loss: 0.005569315515458584
# OrderedDict({'weights': tensor([0.6724]), 'bias': tensor([0.3118])})
# OrderedDict({'weights': tensor([0.6740]), 'bias': tensor([0.3108])})
# =============================================================================================
# Loss: 0.005222178064286709
# OrderedDict({'weights': tensor([0.6740]), 'bias': tensor([0.3108])})
# OrderedDict({'weights': tensor([0.6758]), 'bias': tensor([0.3103])})
# =============================================================================================
# Loss: 0.004880306776612997
# OrderedDict({'weights': tensor([0.6758]), 'bias': tensor([0.3103])})
# OrderedDict({'weights': tensor([0.6774]), 'bias': tensor([0.3093])})
# =============================================================================================
# Loss: 0.004536976106464863
# OrderedDict({'weights': tensor([0.6774]), 'bias': tensor([0.3093])})
# OrderedDict({'weights': tensor([0.6792]), 'bias': tensor([0.3088])})
# =============================================================================================
# Loss: 0.00419129803776741
# OrderedDict({'weights': tensor([0.6792]), 'bias': tensor([0.3088])})
# OrderedDict({'weights': tensor([0.6808]), 'bias': tensor([0.3078])})
# =============================================================================================
# Loss: 0.0038517764769494534
# OrderedDict({'weights': tensor([0.6808]), 'bias': tensor([0.3078])})
# OrderedDict({'weights': tensor([0.6826]), 'bias': tensor([0.3073])})
# Epoch: 160 | Loss: 0.0038517764769494534 | Test loss:0.008201557211577892
# =============================================================================================
# Loss: 0.0035027749836444855
# OrderedDict({'weights': tensor([0.6826]), 'bias': tensor([0.3073])})
# OrderedDict({'weights': tensor([0.6844]), 'bias': tensor([0.3068])})
# =============================================================================================
# Loss: 0.0031660839449614286
# OrderedDict({'weights': tensor([0.6844]), 'bias': tensor([0.3068])})
# OrderedDict({'weights': tensor([0.6860]), 'bias': tensor([0.3058])})
# =============================================================================================
# Loss: 0.002817571861669421
# OrderedDict({'weights': tensor([0.6860]), 'bias': tensor([0.3058])})
# OrderedDict({'weights': tensor([0.6878]), 'bias': tensor([0.3053])})
# =============================================================================================
# Loss: 0.0024770735763013363
# OrderedDict({'weights': tensor([0.6878]), 'bias': tensor([0.3053])})
# OrderedDict({'weights': tensor([0.6894]), 'bias': tensor([0.3043])})
# =============================================================================================
# Loss: 0.0021323717664927244
# OrderedDict({'weights': tensor([0.6894]), 'bias': tensor([0.3043])})
# OrderedDict({'weights': tensor([0.6912]), 'bias': tensor([0.3038])})
# =============================================================================================
# Loss: 0.0017880648374557495
# OrderedDict({'weights': tensor([0.6912]), 'bias': tensor([0.3038])})
# OrderedDict({'weights': tensor([0.6915]), 'bias': tensor([0.3036])})
# =============================================================================================
# Loss: 0.001699858927167952
# OrderedDict({'weights': tensor([0.6915]), 'bias': tensor([0.3036])})
# OrderedDict({'weights': tensor([0.6919]), 'bias': tensor([0.3033])})
# =============================================================================================
# Loss: 0.0016152687603607774
# OrderedDict({'weights': tensor([0.6919]), 'bias': tensor([0.3033])})
# OrderedDict({'weights': tensor([0.6924]), 'bias': tensor([0.3032])})
# =============================================================================================
# Loss: 0.0015280165243893862
# OrderedDict({'weights': tensor([0.6924]), 'bias': tensor([0.3032])})
# OrderedDict({'weights': tensor([0.6928]), 'bias': tensor([0.3031])})
# =============================================================================================
# Loss: 0.0014435537159442902
# OrderedDict({'weights': tensor([0.6928]), 'bias': tensor([0.3031])})
# OrderedDict({'weights': tensor([0.6932]), 'bias': tensor([0.3028])})
# Epoch: 170 | Loss: 0.0014435537159442902 | Test loss:0.0032029212452471256
# =============================================================================================
# Loss: 0.001356709748506546
# OrderedDict({'weights': tensor([0.6932]), 'bias': tensor([0.3028])})
# OrderedDict({'weights': tensor([0.6937]), 'bias': tensor([0.3027])})
# =============================================================================================
# Loss: 0.0012712932657450438
# OrderedDict({'weights': tensor([0.6937]), 'bias': tensor([0.3027])})
# OrderedDict({'weights': tensor([0.6941]), 'bias': tensor([0.3024])})
# =============================================================================================
# Loss: 0.001185414963401854
# OrderedDict({'weights': tensor([0.6941]), 'bias': tensor([0.3024])})
# OrderedDict({'weights': tensor([0.6945]), 'bias': tensor([0.3023])})
# =============================================================================================
# Loss: 0.0010990418959408998
# OrderedDict({'weights': tensor([0.6945]), 'bias': tensor([0.3023])})
# OrderedDict({'weights': tensor([0.6949]), 'bias': tensor([0.3021])})
# =============================================================================================
# Loss: 0.0010141037637367845
# OrderedDict({'weights': tensor([0.6949]), 'bias': tensor([0.3021])})
# OrderedDict({'weights': tensor([0.6954]), 'bias': tensor([0.3019])})
# =============================================================================================
# Loss: 0.0009268544381484389
# OrderedDict({'weights': tensor([0.6954]), 'bias': tensor([0.3019])})
# OrderedDict({'weights': tensor([0.6958]), 'bias': tensor([0.3018])})
# =============================================================================================
# Loss: 0.0008427314460277557
# OrderedDict({'weights': tensor([0.6958]), 'bias': tensor([0.3018])})
# OrderedDict({'weights': tensor([0.6962]), 'bias': tensor([0.3016])})
# =============================================================================================
# Loss: 0.0007555425399914384
# OrderedDict({'weights': tensor([0.6962]), 'bias': tensor([0.3016])})
# OrderedDict({'weights': tensor([0.6967]), 'bias': tensor([0.3014])})
# =============================================================================================
# Loss: 0.0006704777479171753
# OrderedDict({'weights': tensor([0.6967]), 'bias': tensor([0.3014])})
# OrderedDict({'weights': tensor([0.6971]), 'bias': tensor([0.3012])})
# =============================================================================================
# Loss: 0.0005842484533786774
# OrderedDict({'weights': tensor([0.6971]), 'bias': tensor([0.3012])})
# OrderedDict({'weights': tensor([0.6975]), 'bias': tensor([0.3011])})
# Epoch: 180 | Loss: 0.0005842484533786774 | Test loss:0.001134723424911499
# =============================================================================================
# Loss: 0.0004982225364074111
# OrderedDict({'weights': tensor([0.6975]), 'bias': tensor([0.3011])})
# OrderedDict({'weights': tensor([0.6979]), 'bias': tensor([0.3008])})
# =============================================================================================
# Loss: 0.00041380448965355754
# OrderedDict({'weights': tensor([0.6979]), 'bias': tensor([0.3008])})
# OrderedDict({'weights': tensor([0.6984]), 'bias': tensor([0.3008])})
# =============================================================================================
# Loss: 0.00034511982812546194
# OrderedDict({'weights': tensor([0.6984]), 'bias': tensor([0.3008])})
# OrderedDict({'weights': tensor([0.6986]), 'bias': tensor([0.3001])})
# =============================================================================================
# Loss: 0.0004929311689920723
# OrderedDict({'weights': tensor([0.6986]), 'bias': tensor([0.3001])})
# OrderedDict({'weights': tensor([0.6996]), 'bias': tensor([0.3022])})
# =============================================================================================

# %%
epoch = torch.arange(1,186,1)

# %%
# Plot the loss curves
def plot_loss(epoch, train_loss, test_loss_):
    '''
    Plot the test loss along with the epoch
    '''
    plt.figure(figsize=(10,7))
    plt.plot(epoch, train_loss, label="train loss")
    plt.plot(epoch, test_loss_, label="test loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.title("Train and test loss curves")
    plt.legend(prop={"size":14})

# %%
plot_loss(epoch, train_loss, test_loss_)

# %%
with torch.inference_mode(): 
    test_preds = model_0(X_test)
plot_predictions(predictions=test_preds)

# %%
weight, bias
# Out:
# (0.7, 0.3)

# %%
list_loss
# Out:
# [{'epoch': 0, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 1, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 2, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 3, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 4, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 5, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 6, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 7, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 8, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 9, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 10, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 11, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 12, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 13, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 14, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 15, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 16, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 17, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 18, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 19, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 20, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 21, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 22, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 23, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 24, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 25, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 26, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 27, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 28, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 29, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 30, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 31, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 32, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 33, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 34, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 35, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 36, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 37, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 38, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 39, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 40, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 41, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 42, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 43, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 44, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 45, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 46, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 47, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 48, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 49, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 50, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 51, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 52, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 53, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 54, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 55, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 56, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 57, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 58, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 59, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 60, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 61, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 62, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 63, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 64, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 65, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 66, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 67, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 68, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 69, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 70, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 71, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 72, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 73, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 74, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 75, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 76, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 77, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 78, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 79, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 80, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 81, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 82, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 83, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 84, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 85, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 86, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 87, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 88, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 89, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 90, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 91, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 92, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 93, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 94, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 95, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 96, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 97, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 98, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 99, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 100, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 101, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 102, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 103, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 104, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 105, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 106, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 107, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 108, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 109, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 110, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 111, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 112, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 113, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 114, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 115, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 116, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 117, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 118, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 119, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 120, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 121, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 122, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 123, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 124, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 125, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 126, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 127, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 128, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 129, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 130, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 131, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 132, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 133, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 134, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 135, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 136, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 137, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 138, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 139, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 140, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 141, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 142, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 143, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 144, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 145, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 146, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 147, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 148, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 149, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 150, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 151, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 152, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 153, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 154, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 155, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 156, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 157, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 158, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 159, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 160, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 161, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 162, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 163, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 164, 'weights': 0.6986, 'bias': 0.2997},
#  {'epoch': 165, 'weights': 0.6996, 'bias': 0.3022},
#  {'epoch': 166, 'weights': 0.6993, 'bias': 0.3016},
#  {'epoch': 167, 'weights': 0.6991, 'bias': 0.3009},
#  {'epoch': 168, 'weights': 0.6988, 'bias': 0.3003},
#  {'epoch': 169, 'weights': 0.699, 'bias': 0.3005},
#  {'epoch': 170, 'weights': 0.6991, 'bias': 0.3003},
#  {'epoch': 171, 'weights': 0.6992, 'bias': 0.3004},
#  {'epoch': 172, 'weights': 0.6993, 'bias': 0.3002},
#  {'epoch': 173, 'weights': 0.6994, 'bias': 0.3004},
#  {'epoch': 174, 'weights': 0.6993, 'bias': 0.3},
#  {'epoch': 175, 'weights': 0.6996, 'bias': 0.3006},
#  {'epoch': 176, 'weights': 0.6993, 'bias': 0.3},
#  {'epoch': 177, 'weights': 0.6996, 'bias': 0.3006},
#  {'epoch': 178, 'weights': 0.6993, 'bias': 0.3},
#  {'epoch': 179, 'weights': 0.6996, 'bias': 0.3006},
#  {'epoch': 180, 'weights': 0.6993, 'bias': 0.3},
#  {'epoch': 181, 'weights': 0.6996, 'bias': 0.3006},
#  {'epoch': 182, 'weights': 0.6993, 'bias': 0.3},
#  {'epoch': 183, 'weights': 0.6996, 'bias': 0.3006},
#  {'epoch': 184, 'weights': 0.6993, 'bias': 0.3}]

# %% [markdown]
# ## Saving a model in PyTorch
# There are three main methods you should know about to save and load a model in PyTorch
#
# 1. `torch.save()` - allows you save a PyTorch object in Python's pickle format
# 2. `torch.load()` - allows you to load a saved PyTorch object
# 3. `torch.nn.Module.load_state_dict()` - allows you to load a model's saved state dictionary
#
# PyTorch save and load code tutorial + extra-curriculum - https://pytorch.org/tutorials/beginner/saving_loading_models.html

# %%
# Create a function to save a model
def save_model(model_name, model):
    # Saving our PyTorch model
    from pathlib import Path

    # 1. Create models directory
    MODEL_PATH = Path("models")
    MODEL_PATH.mkdir(parents=True, exist_ok=True)

    # 2. Create model save path
    MODEL_NAME = model_name
    MODEL_SAVE_PATH = MODEL_PATH / MODEL_NAME

    # 3. Save the model state dict
    print(f"Saving model to: {MODEL_SAVE_PATH}")
    torch.save(obj=model.state_dict(),
            f=MODEL_SAVE_PATH)

# %%
# Save model 0
save_model("01_pytorch_workflow_model_0.pth", model_0)
# Out:
# Saving model to: models/01_pytorch_workflow_model_0.pth

# %% [markdown]
# ## Loading our PyTorch model
#
# Since we saved our model's state dict rather than the entire model, we'll create a new instance
# of our model class and load the saved `state_dict()` into that.

# %%
# Create a function to load a model
def load_model(model_name, model_class):
    # To load in a save state_dict(), we have to instantiate a new instance of our model class
    loaded_model = model_class

    # Load the saved state_dict() of model_0 (this will update the new instance with updated parameters)
    from pathlib import Path
    MODEL_PATH = Path("models")
    MODEL_NAME = model_name
    MODEL_SAVE_PATH = MODEL_PATH / MODEL_NAME
    loaded_model.load_state_dict(torch.load(MODEL_SAVE_PATH))

    # Evaluate the loaded model
    loaded_model.state_dict()
    print(f"Loaded model {model_name} from: {MODEL_SAVE_PATH}")
    # Return the model
    return loaded_model

# %%
# Load model 0 
loaded_model_0 = load_model("01_pytorch_workflow_model_0.pth", LinearRegressionModel())
# Out:
# Loaded model 01_pytorch_workflow_model_0.pth from: models/01_pytorch_workflow_model_0.pth

# %%
# Make some predictions
loaded_model_0.eval()
with torch.inference_mode():
    loaded_model_preds = loaded_model_0(X_test)
loaded_model_preds
# Out:
# tensor([[0.8618],
#         [0.8758],
#         [0.8898],
#         [0.9038],
#         [0.9178],
#         [0.9318],
#         [0.9458],
#         [0.9598],
#         [0.9738],
#         [0.9878]])

# %%
# Compare loaded model preds with original model preds
test_pred == loaded_model_preds
# Out:
# tensor([[True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True]])

# %% [markdown]
# ### 6. Putting all together
#
# Let's go back through the steps above and see it all in one place.

# %% [markdown]
# ### 6.2 Building a PyTorch Linear model

# %%
# Create a linear model by subclassing nn.Module
class LinearModelRegressionV2(nn.Module):
    def __init__(self):
        super().__init__()
        # Use nn.Linear() for creating the model parameters / also called: linear transform, probing layer, fully connected layer, dense layer
        self.linear_layer = nn.Linear(in_features=1,
                                      out_features=1)
        
    def forward(self, x: torch.tensor) -> torch.tensor:
        return self.linear_layer(x)
    
# Set the manual seed
torch.manual_seed(42)
model_1 = LinearModelRegressionV2()
model_1, model_1.state_dict()
# Out:
# (LinearModelRegressionV2(
#    (linear_layer): Linear(in_features=1, out_features=1, bias=True)
#  ),
#  OrderedDict([('linear_layer.weight', tensor([[0.7645]])),
#               ('linear_layer.bias', tensor([0.8300]))]))

# %% [markdown]
# ### 6.3 Training code
#
# For training we need:
# * Loss function
# * Optimizer
# * Training Loop
# * Testing Loop

# %%
# Setup loss function
loss_fn = nn.L1Loss()

# Setup our optimizer
optimizer = torch.optim.SGD(params=model_1.parameters(),
                            lr=0.01)

# %%
# Let's write a training loop
torch.manual_seed(42)
list_loss = []
epochs = 140

for epoch in range(epochs):
    model_1.train()
    dict_loss = {}

    # 1. Forward pass
    y_pred = model_1(X_train)

    # 2. Calculate the loss
    loss = loss_fn(y_pred, y_train)

    # 3. Optimizer zero grad
    optimizer.zero_grad()

    # 4. Perform backpropagation
    loss.backward()
    print(f"Epoch: {epoch} ", model_1.state_dict())

    # 5. Optimizer Step
    optimizer.step()

    ### Testing
    model_1.eval()
    with torch.inference_mode():
        test_pred = model_1(X_test)
        test_loss = loss_fn(test_pred, y_test)

    # Reducing the learning rate
    
    if epoch == 110:
        optimizer.param_groups[0]['lr'] /=4

    # Print out what's happening

    if epoch % 10 == 0:
        print(f"Train loss: {loss} | Test loss: {test_loss} ")

    # Make a dictionnary of the values and add it to a list for each epoch
    dict_loss["epoch"] = epoch
    dict_loss["train loss"] = round(loss.item(), 4)
    dict_loss["test loss"] = round(test_loss.item(),4)
    dict_loss["weights"] = round(model_0.weights[0].item(),4)
    dict_loss["bias"] = round(model_0.bias[0].item(),4)

    list_loss.append(dict_loss)
    print(f"=========================================================================================================")
# Out:
# Epoch: 0  OrderedDict([('linear_layer.weight', tensor([[0.7645]])), ('linear_layer.bias', tensor([0.8300]))])
# Train loss: 0.5551779866218567 | Test loss: 0.5739762187004089
# =========================================================================================================
# Epoch: 1  OrderedDict([('linear_layer.weight', tensor([[0.7606]])), ('linear_layer.bias', tensor([0.8200]))])
# =========================================================================================================
# Epoch: 2  OrderedDict([('linear_layer.weight', tensor([[0.7567]])), ('linear_layer.bias', tensor([0.8100]))])
# =========================================================================================================
# Epoch: 3  OrderedDict([('linear_layer.weight', tensor([[0.7528]])), ('linear_layer.bias', tensor([0.8000]))])
# =========================================================================================================
# Epoch: 4  OrderedDict([('linear_layer.weight', tensor([[0.7489]])), ('linear_layer.bias', tensor([0.7900]))])
# =========================================================================================================
# Epoch: 5  OrderedDict([('linear_layer.weight', tensor([[0.7450]])), ('linear_layer.bias', tensor([0.7800]))])
# =========================================================================================================
# Epoch: 6  OrderedDict([('linear_layer.weight', tensor([[0.7411]])), ('linear_layer.bias', tensor([0.7700]))])
# =========================================================================================================
# Epoch: 7  OrderedDict([('linear_layer.weight', tensor([[0.7372]])), ('linear_layer.bias', tensor([0.7600]))])
# =========================================================================================================
# Epoch: 8  OrderedDict([('linear_layer.weight', tensor([[0.7333]])), ('linear_layer.bias', tensor([0.7500]))])
# =========================================================================================================
# Epoch: 9  OrderedDict([('linear_layer.weight', tensor([[0.7294]])), ('linear_layer.bias', tensor([0.7400]))])
# =========================================================================================================
# Epoch: 10  OrderedDict([('linear_layer.weight', tensor([[0.7255]])), ('linear_layer.bias', tensor([0.7300]))])
# Train loss: 0.4399680495262146 | Test loss: 0.4392663538455963
# =========================================================================================================
# Epoch: 11  OrderedDict([('linear_layer.weight', tensor([[0.7216]])), ('linear_layer.bias', tensor([0.7200]))])
# =========================================================================================================
# Epoch: 12  OrderedDict([('linear_layer.weight', tensor([[0.7177]])), ('linear_layer.bias', tensor([0.7100]))])
# =========================================================================================================
# Epoch: 13  OrderedDict([('linear_layer.weight', tensor([[0.7138]])), ('linear_layer.bias', tensor([0.7000]))])
# =========================================================================================================
# Epoch: 14  OrderedDict([('linear_layer.weight', tensor([[0.7099]])), ('linear_layer.bias', tensor([0.6900]))])
# =========================================================================================================
# Epoch: 15  OrderedDict([('linear_layer.weight', tensor([[0.7060]])), ('linear_layer.bias', tensor([0.6800]))])
# =========================================================================================================
# Epoch: 16  OrderedDict([('linear_layer.weight', tensor([[0.7021]])), ('linear_layer.bias', tensor([0.6700]))])
# =========================================================================================================
# Epoch: 17  OrderedDict([('linear_layer.weight', tensor([[0.6982]])), ('linear_layer.bias', tensor([0.6600]))])
# =========================================================================================================
# Epoch: 18  OrderedDict([('linear_layer.weight', tensor([[0.6943]])), ('linear_layer.bias', tensor([0.6500]))])
# =========================================================================================================
# Epoch: 19  OrderedDict([('linear_layer.weight', tensor([[0.6904]])), ('linear_layer.bias', tensor([0.6400]))])
# =========================================================================================================
# Epoch: 20  OrderedDict([('linear_layer.weight', tensor([[0.6865]])), ('linear_layer.bias', tensor([0.6300]))])
# Train loss: 0.3247582018375397 | Test loss: 0.30455657839775085
# =========================================================================================================
# Epoch: 21  OrderedDict([('linear_layer.weight', tensor([[0.6826]])), ('linear_layer.bias', tensor([0.6200]))])
# =========================================================================================================
# Epoch: 22  OrderedDict([('linear_layer.weight', tensor([[0.6787]])), ('linear_layer.bias', tensor([0.6100]))])
# =========================================================================================================
# Epoch: 23  OrderedDict([('linear_layer.weight', tensor([[0.6748]])), ('linear_layer.bias', tensor([0.6000]))])
# =========================================================================================================
# Epoch: 24  OrderedDict([('linear_layer.weight', tensor([[0.6709]])), ('linear_layer.bias', tensor([0.5900]))])
# =========================================================================================================
# Epoch: 25  OrderedDict([('linear_layer.weight', tensor([[0.6670]])), ('linear_layer.bias', tensor([0.5800]))])
# =========================================================================================================
# Epoch: 26  OrderedDict([('linear_layer.weight', tensor([[0.6631]])), ('linear_layer.bias', tensor([0.5700]))])
# =========================================================================================================
# Epoch: 27  OrderedDict([('linear_layer.weight', tensor([[0.6592]])), ('linear_layer.bias', tensor([0.5600]))])
# =========================================================================================================
# Epoch: 28  OrderedDict([('linear_layer.weight', tensor([[0.6553]])), ('linear_layer.bias', tensor([0.5500]))])
# =========================================================================================================
# Epoch: 29  OrderedDict([('linear_layer.weight', tensor([[0.6514]])), ('linear_layer.bias', tensor([0.5400]))])
# =========================================================================================================
# Epoch: 30  OrderedDict([('linear_layer.weight', tensor([[0.6475]])), ('linear_layer.bias', tensor([0.5300]))])
# Train loss: 0.20954827964305878 | Test loss: 0.16984674334526062
# =========================================================================================================
# Epoch: 31  OrderedDict([('linear_layer.weight', tensor([[0.6436]])), ('linear_layer.bias', tensor([0.5200]))])
# =========================================================================================================
# Epoch: 32  OrderedDict([('linear_layer.weight', tensor([[0.6397]])), ('linear_layer.bias', tensor([0.5100]))])
# =========================================================================================================
# Epoch: 33  OrderedDict([('linear_layer.weight', tensor([[0.6358]])), ('linear_layer.bias', tensor([0.5000]))])
# =========================================================================================================
# Epoch: 34  OrderedDict([('linear_layer.weight', tensor([[0.6319]])), ('linear_layer.bias', tensor([0.4900]))])
# =========================================================================================================
# Epoch: 35  OrderedDict([('linear_layer.weight', tensor([[0.6280]])), ('linear_layer.bias', tensor([0.4800]))])
# =========================================================================================================
# Epoch: 36  OrderedDict([('linear_layer.weight', tensor([[0.6241]])), ('linear_layer.bias', tensor([0.4700]))])
# =========================================================================================================
# Epoch: 37  OrderedDict([('linear_layer.weight', tensor([[0.6202]])), ('linear_layer.bias', tensor([0.4600]))])
# =========================================================================================================
# Epoch: 38  OrderedDict([('linear_layer.weight', tensor([[0.6163]])), ('linear_layer.bias', tensor([0.4500]))])
# =========================================================================================================
# Epoch: 39  OrderedDict([('linear_layer.weight', tensor([[0.6124]])), ('linear_layer.bias', tensor([0.4400]))])
# =========================================================================================================
# Epoch: 40  OrderedDict([('linear_layer.weight', tensor([[0.6085]])), ('linear_layer.bias', tensor([0.4300]))])
# Train loss: 0.09433844685554504 | Test loss: 0.03513689711689949
# =========================================================================================================
# Epoch: 41  OrderedDict([('linear_layer.weight', tensor([[0.6046]])), ('linear_layer.bias', tensor([0.4200]))])
# =========================================================================================================
# Epoch: 42  OrderedDict([('linear_layer.weight', tensor([[0.6007]])), ('linear_layer.bias', tensor([0.4100]))])
# =========================================================================================================
# Epoch: 43  OrderedDict([('linear_layer.weight', tensor([[0.5968]])), ('linear_layer.bias', tensor([0.4000]))])
# =========================================================================================================
# Epoch: 44  OrderedDict([('linear_layer.weight', tensor([[0.5929]])), ('linear_layer.bias', tensor([0.3900]))])
# =========================================================================================================
# Epoch: 45  OrderedDict([('linear_layer.weight', tensor([[0.5890]])), ('linear_layer.bias', tensor([0.3800]))])
# =========================================================================================================
# Epoch: 46  OrderedDict([('linear_layer.weight', tensor([[0.5863]])), ('linear_layer.bias', tensor([0.3715]))])
# =========================================================================================================
# Epoch: 47  OrderedDict([('linear_layer.weight', tensor([[0.5852]])), ('linear_layer.bias', tensor([0.3655]))])
# =========================================================================================================
# Epoch: 48  OrderedDict([('linear_layer.weight', tensor([[0.5851]])), ('linear_layer.bias', tensor([0.3610]))])
# =========================================================================================================
# Epoch: 49  OrderedDict([('linear_layer.weight', tensor([[0.5854]])), ('linear_layer.bias', tensor([0.3575]))])
# =========================================================================================================
# Epoch: 50  OrderedDict([('linear_layer.weight', tensor([[0.5861]])), ('linear_layer.bias', tensor([0.3545]))])
# Train loss: 0.023886386305093765 | Test loss: 0.04784906655550003
# =========================================================================================================
# Epoch: 51  OrderedDict([('linear_layer.weight', tensor([[0.5872]])), ('linear_layer.bias', tensor([0.3525]))])
# =========================================================================================================
# Epoch: 52  OrderedDict([('linear_layer.weight', tensor([[0.5884]])), ('linear_layer.bias', tensor([0.3505]))])
# =========================================================================================================
# Epoch: 53  OrderedDict([('linear_layer.weight', tensor([[0.5897]])), ('linear_layer.bias', tensor([0.3490]))])
# =========================================================================================================
# Epoch: 54  OrderedDict([('linear_layer.weight', tensor([[0.5911]])), ('linear_layer.bias', tensor([0.3475]))])
# =========================================================================================================
# Epoch: 55  OrderedDict([('linear_layer.weight', tensor([[0.5927]])), ('linear_layer.bias', tensor([0.3465]))])
# =========================================================================================================
# Epoch: 56  OrderedDict([('linear_layer.weight', tensor([[0.5943]])), ('linear_layer.bias', tensor([0.3455]))])
# =========================================================================================================
# Epoch: 57  OrderedDict([('linear_layer.weight', tensor([[0.5959]])), ('linear_layer.bias', tensor([0.3445]))])
# =========================================================================================================
# Epoch: 58  OrderedDict([('linear_layer.weight', tensor([[0.5975]])), ('linear_layer.bias', tensor([0.3435]))])
# =========================================================================================================
# Epoch: 59  OrderedDict([('linear_layer.weight', tensor([[0.5991]])), ('linear_layer.bias', tensor([0.3425]))])
# =========================================================================================================
# Epoch: 60  OrderedDict([('linear_layer.weight', tensor([[0.6007]])), ('linear_layer.bias', tensor([0.3415]))])
# Train loss: 0.0199567973613739 | Test loss: 0.04580312222242355
# =========================================================================================================
# Epoch: 61  OrderedDict([('linear_layer.weight', tensor([[0.6025]])), ('linear_layer.bias', tensor([0.3410]))])
# =========================================================================================================
# Epoch: 62  OrderedDict([('linear_layer.weight', tensor([[0.6040]])), ('linear_layer.bias', tensor([0.3400]))])
# =========================================================================================================
# Epoch: 63  OrderedDict([('linear_layer.weight', tensor([[0.6058]])), ('linear_layer.bias', tensor([0.3395]))])
# =========================================================================================================
# Epoch: 64  OrderedDict([('linear_layer.weight', tensor([[0.6076]])), ('linear_layer.bias', tensor([0.3390]))])
# =========================================================================================================
# Epoch: 65  OrderedDict([('linear_layer.weight', tensor([[0.6092]])), ('linear_layer.bias', tensor([0.3380]))])
# =========================================================================================================
# Epoch: 66  OrderedDict([('linear_layer.weight', tensor([[0.6110]])), ('linear_layer.bias', tensor([0.3375]))])
# =========================================================================================================
# Epoch: 67  OrderedDict([('linear_layer.weight', tensor([[0.6126]])), ('linear_layer.bias', tensor([0.3365]))])
# =========================================================================================================
# Epoch: 68  OrderedDict([('linear_layer.weight', tensor([[0.6144]])), ('linear_layer.bias', tensor([0.3360]))])
# =========================================================================================================
# Epoch: 69  OrderedDict([('linear_layer.weight', tensor([[0.6160]])), ('linear_layer.bias', tensor([0.3350]))])
# =========================================================================================================
# Epoch: 70  OrderedDict([('linear_layer.weight', tensor([[0.6178]])), ('linear_layer.bias', tensor([0.3345]))])
# Train loss: 0.016517987474799156 | Test loss: 0.0375305712223053
# =========================================================================================================
# Epoch: 71  OrderedDict([('linear_layer.weight', tensor([[0.6196]])), ('linear_layer.bias', tensor([0.3340]))])
# =========================================================================================================
# Epoch: 72  OrderedDict([('linear_layer.weight', tensor([[0.6212]])), ('linear_layer.bias', tensor([0.3330]))])
# =========================================================================================================
# Epoch: 73  OrderedDict([('linear_layer.weight', tensor([[0.6230]])), ('linear_layer.bias', tensor([0.3325]))])
# =========================================================================================================
# Epoch: 74  OrderedDict([('linear_layer.weight', tensor([[0.6246]])), ('linear_layer.bias', tensor([0.3315]))])
# =========================================================================================================
# Epoch: 75  OrderedDict([('linear_layer.weight', tensor([[0.6264]])), ('linear_layer.bias', tensor([0.3310]))])
# =========================================================================================================
# Epoch: 76  OrderedDict([('linear_layer.weight', tensor([[0.6280]])), ('linear_layer.bias', tensor([0.3300]))])
# =========================================================================================================
# Epoch: 77  OrderedDict([('linear_layer.weight', tensor([[0.6298]])), ('linear_layer.bias', tensor([0.3295]))])
# =========================================================================================================
# Epoch: 78  OrderedDict([('linear_layer.weight', tensor([[0.6314]])), ('linear_layer.bias', tensor([0.3285]))])
# =========================================================================================================
# Epoch: 79  OrderedDict([('linear_layer.weight', tensor([[0.6332]])), ('linear_layer.bias', tensor([0.3280]))])
# =========================================================================================================
# Epoch: 80  OrderedDict([('linear_layer.weight', tensor([[0.6350]])), ('linear_layer.bias', tensor([0.3275]))])
# Train loss: 0.013089170679450035 | Test loss: 0.029944902285933495
# =========================================================================================================
# Epoch: 81  OrderedDict([('linear_layer.weight', tensor([[0.6366]])), ('linear_layer.bias', tensor([0.3265]))])
# =========================================================================================================
# Epoch: 82  OrderedDict([('linear_layer.weight', tensor([[0.6384]])), ('linear_layer.bias', tensor([0.3260]))])
# =========================================================================================================
# Epoch: 83  OrderedDict([('linear_layer.weight', tensor([[0.6400]])), ('linear_layer.bias', tensor([0.3250]))])
# =========================================================================================================
# Epoch: 84  OrderedDict([('linear_layer.weight', tensor([[0.6418]])), ('linear_layer.bias', tensor([0.3245]))])
# =========================================================================================================
# Epoch: 85  OrderedDict([('linear_layer.weight', tensor([[0.6433]])), ('linear_layer.bias', tensor([0.3235]))])
# =========================================================================================================
# Epoch: 86  OrderedDict([('linear_layer.weight', tensor([[0.6451]])), ('linear_layer.bias', tensor([0.3230]))])
# =========================================================================================================
# Epoch: 87  OrderedDict([('linear_layer.weight', tensor([[0.6469]])), ('linear_layer.bias', tensor([0.3225]))])
# =========================================================================================================
# Epoch: 88  OrderedDict([('linear_layer.weight', tensor([[0.6485]])), ('linear_layer.bias', tensor([0.3215]))])
# =========================================================================================================
# Epoch: 89  OrderedDict([('linear_layer.weight', tensor([[0.6503]])), ('linear_layer.bias', tensor([0.3210]))])
# =========================================================================================================
# Epoch: 90  OrderedDict([('linear_layer.weight', tensor([[0.6519]])), ('linear_layer.bias', tensor([0.3200]))])
# Train loss: 0.009653178043663502 | Test loss: 0.02167237363755703
# =========================================================================================================
# Epoch: 91  OrderedDict([('linear_layer.weight', tensor([[0.6537]])), ('linear_layer.bias', tensor([0.3195]))])
# =========================================================================================================
# Epoch: 92  OrderedDict([('linear_layer.weight', tensor([[0.6553]])), ('linear_layer.bias', tensor([0.3185]))])
# =========================================================================================================
# Epoch: 93  OrderedDict([('linear_layer.weight', tensor([[0.6571]])), ('linear_layer.bias', tensor([0.3180]))])
# =========================================================================================================
# Epoch: 94  OrderedDict([('linear_layer.weight', tensor([[0.6589]])), ('linear_layer.bias', tensor([0.3175]))])
# =========================================================================================================
# Epoch: 95  OrderedDict([('linear_layer.weight', tensor([[0.6605]])), ('linear_layer.bias', tensor([0.3165]))])
# =========================================================================================================
# Epoch: 96  OrderedDict([('linear_layer.weight', tensor([[0.6623]])), ('linear_layer.bias', tensor([0.3160]))])
# =========================================================================================================
# Epoch: 97  OrderedDict([('linear_layer.weight', tensor([[0.6639]])), ('linear_layer.bias', tensor([0.3150]))])
# =========================================================================================================
# Epoch: 98  OrderedDict([('linear_layer.weight', tensor([[0.6657]])), ('linear_layer.bias', tensor([0.3145]))])
# =========================================================================================================
# Epoch: 99  OrderedDict([('linear_layer.weight', tensor([[0.6673]])), ('linear_layer.bias', tensor([0.3135]))])
# =========================================================================================================
# Epoch: 100  OrderedDict([('linear_layer.weight', tensor([[0.6691]])), ('linear_layer.bias', tensor([0.3130]))])
# Train loss: 0.006215679459273815 | Test loss: 0.014086711220443249
# =========================================================================================================
# Epoch: 101  OrderedDict([('linear_layer.weight', tensor([[0.6707]])), ('linear_layer.bias', tensor([0.3120]))])
# =========================================================================================================
# Epoch: 102  OrderedDict([('linear_layer.weight', tensor([[0.6725]])), ('linear_layer.bias', tensor([0.3115]))])
# =========================================================================================================
# Epoch: 103  OrderedDict([('linear_layer.weight', tensor([[0.6743]])), ('linear_layer.bias', tensor([0.3110]))])
# =========================================================================================================
# Epoch: 104  OrderedDict([('linear_layer.weight', tensor([[0.6759]])), ('linear_layer.bias', tensor([0.3100]))])
# =========================================================================================================
# Epoch: 105  OrderedDict([('linear_layer.weight', tensor([[0.6777]])), ('linear_layer.bias', tensor([0.3095]))])
# =========================================================================================================
# Epoch: 106  OrderedDict([('linear_layer.weight', tensor([[0.6793]])), ('linear_layer.bias', tensor([0.3085]))])
# =========================================================================================================
# Epoch: 107  OrderedDict([('linear_layer.weight', tensor([[0.6811]])), ('linear_layer.bias', tensor([0.3080]))])
# =========================================================================================================
# Epoch: 108  OrderedDict([('linear_layer.weight', tensor([[0.6826]])), ('linear_layer.bias', tensor([0.3070]))])
# =========================================================================================================
# Epoch: 109  OrderedDict([('linear_layer.weight', tensor([[0.6844]])), ('linear_layer.bias', tensor([0.3065]))])
# =========================================================================================================
# Epoch: 110  OrderedDict([('linear_layer.weight', tensor([[0.6862]])), ('linear_layer.bias', tensor([0.3060]))])
# Train loss: 0.002787243574857712 | Test loss: 0.005814164876937866
# =========================================================================================================
# Epoch: 111  OrderedDict([('linear_layer.weight', tensor([[0.6878]])), ('linear_layer.bias', tensor([0.3050]))])
# =========================================================================================================
# Epoch: 112  OrderedDict([('linear_layer.weight', tensor([[0.6883]])), ('linear_layer.bias', tensor([0.3049]))])
# =========================================================================================================
# Epoch: 113  OrderedDict([('linear_layer.weight', tensor([[0.6887]])), ('linear_layer.bias', tensor([0.3048]))])
# =========================================================================================================
# Epoch: 114  OrderedDict([('linear_layer.weight', tensor([[0.6891]])), ('linear_layer.bias', tensor([0.3045]))])
# =========================================================================================================
# Epoch: 115  OrderedDict([('linear_layer.weight', tensor([[0.6896]])), ('linear_layer.bias', tensor([0.3044]))])
# =========================================================================================================
# Epoch: 116  OrderedDict([('linear_layer.weight', tensor([[0.6900]])), ('linear_layer.bias', tensor([0.3041]))])
# =========================================================================================================
# Epoch: 117  OrderedDict([('linear_layer.weight', tensor([[0.6904]])), ('linear_layer.bias', tensor([0.3040]))])
# =========================================================================================================
# Epoch: 118  OrderedDict([('linear_layer.weight', tensor([[0.6909]])), ('linear_layer.bias', tensor([0.3039]))])
# =========================================================================================================
# Epoch: 119  OrderedDict([('linear_layer.weight', tensor([[0.6913]])), ('linear_layer.bias', tensor([0.3036]))])
# =========================================================================================================
# Epoch: 120  OrderedDict([('linear_layer.weight', tensor([[0.6917]])), ('linear_layer.bias', tensor([0.3035]))])
# Train loss: 0.0016655102372169495 | Test loss: 0.0037459670566022396
# =========================================================================================================
# Epoch: 121  OrderedDict([('linear_layer.weight', tensor([[0.6921]])), ('linear_layer.bias', tensor([0.3033]))])
# =========================================================================================================
# Epoch: 122  OrderedDict([('linear_layer.weight', tensor([[0.6926]])), ('linear_layer.bias', tensor([0.3031]))])
# =========================================================================================================
# Epoch: 123  OrderedDict([('linear_layer.weight', tensor([[0.6930]])), ('linear_layer.bias', tensor([0.3029]))])
# =========================================================================================================
# Epoch: 124  OrderedDict([('linear_layer.weight', tensor([[0.6934]])), ('linear_layer.bias', tensor([0.3028]))])
# =========================================================================================================
# Epoch: 125  OrderedDict([('linear_layer.weight', tensor([[0.6939]])), ('linear_layer.bias', tensor([0.3026]))])
# =========================================================================================================
# Epoch: 126  OrderedDict([('linear_layer.weight', tensor([[0.6943]])), ('linear_layer.bias', tensor([0.3024]))])
# =========================================================================================================
# Epoch: 127  OrderedDict([('linear_layer.weight', tensor([[0.6947]])), ('linear_layer.bias', tensor([0.3023]))])
# =========================================================================================================
# Epoch: 128  OrderedDict([('linear_layer.weight', tensor([[0.6951]])), ('linear_layer.bias', tensor([0.3020]))])
# =========================================================================================================
# Epoch: 129  OrderedDict([('linear_layer.weight', tensor([[0.6956]])), ('linear_layer.bias', tensor([0.3019]))])
# =========================================================================================================
# Epoch: 130  OrderedDict([('linear_layer.weight', tensor([[0.6960]])), ('linear_layer.bias', tensor([0.3016]))])
# Train loss: 0.0008071743068285286 | Test loss: 0.0016777694690972567
# =========================================================================================================
# Epoch: 131  OrderedDict([('linear_layer.weight', tensor([[0.6964]])), ('linear_layer.bias', tensor([0.3015]))])
# =========================================================================================================
# Epoch: 132  OrderedDict([('linear_layer.weight', tensor([[0.6968]])), ('linear_layer.bias', tensor([0.3013]))])
# =========================================================================================================
# Epoch: 133  OrderedDict([('linear_layer.weight', tensor([[0.6973]])), ('linear_layer.bias', tensor([0.3013]))])
# =========================================================================================================
# Epoch: 134  OrderedDict([('linear_layer.weight', tensor([[0.6976]])), ('linear_layer.bias', tensor([0.3008]))])
# =========================================================================================================
# Epoch: 135  OrderedDict([('linear_layer.weight', tensor([[0.6983]])), ('linear_layer.bias', tensor([0.3013]))])
# =========================================================================================================
# Epoch: 136  OrderedDict([('linear_layer.weight', tensor([[0.6976]])), ('linear_layer.bias', tensor([0.2991]))])
# =========================================================================================================
# Epoch: 137  OrderedDict([('linear_layer.weight', tensor([[0.6986]])), ('linear_layer.bias', tensor([0.3016]))])
# =========================================================================================================
# Epoch: 138  OrderedDict([('linear_layer.weight', tensor([[0.6976]])), ('linear_layer.bias', tensor([0.2991]))])
# =========================================================================================================
# Epoch: 139  OrderedDict([('linear_layer.weight', tensor([[0.6986]])), ('linear_layer.bias', tensor([0.3016]))])
# =========================================================================================================

# %%
test_loss = []
for dict_loss in list_loss:
    test_loss.append(dict_loss["test loss"])
train_loss = []
for dict_loss in list_loss:
    train_loss.append(dict_loss["train loss"])
epoch = torch.arange(1,141,1)

# %%
# Plot loss curves
plot_loss(epoch, train_loss, test_loss)

# %%
# Turn model into evaluation mode
model_1.eval()

# Make predictions on the test data and plot it
with torch.inference_mode(): 
    test_preds = model_1(X_test)
plot_predictions(predictions=test_preds)

# %% [markdown]
# ### 6.5 Saving and loading a trained model

# %%
# Save model 1
save_model("01_pytorch_workflow_model_1.pth", model_1)
# Out:
# Saving model to: models\01_pytorch_workflow_model_1.pth

# %%
# Load model 1
loaded_model_1 = load_model("01_pytorch_workflow_model_1.pth", LinearModelRegressionV2())

# %%
# Make some predictions
loaded_model_1.eval()
with torch.inference_mode():
    loaded_model_preds = loaded_model_1(X_test)
loaded_model_preds == test_preds
# Out:
# tensor([[True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True],
#         [True]])

# %%
loaded_model_1.state_dict()
# Out:
# OrderedDict([('linear_layer.weight', tensor([[0.6976]])),
#              ('linear_layer.bias', tensor([0.2991]))])

# %%
model_1.state_dict()
# Out:
# OrderedDict([('linear_layer.weight', tensor([[0.6976]])),
#              ('linear_layer.bias', tensor([0.2991]))])
