# %% [markdown]
# # Project Bird Vision 🐦 👁
#
# 🎯 The goal of this project is to build a model able to predict the breed of an image with more 95% accuracy.
#
# For this project, I will import a dataset from TensorFlow Datasets. I will be able to use mixed precision training, these are good datasets and it handles downloading and preparing the data deterministically and constructing a `tf.data.Dataset` (or `np.array`).
#
# ## What I'm going to cover
#
# * Using TensorFlow Datasets to download and explore data
# * Creating preprocessing function for our data
# <!-- * Batching & preparing datasets for modelling (**making our datasets run fast**) -->
# * Creating modelling callbacks
# <!-- * Setting up **mixed precision training** -->
# * Building a feature extraction model
# * Fine-tuning the feature extraction model
# * Viewing training results on TensorBoard
# * Evaluate predictions
# * Viewing predictions on test images
# * Viewing the most wrong predictions
# * Viewing predictions on custom images

# %% [markdown]
# ## Create helper functions

# %%
# Get our helper functions
with open("helper_functions.py", "r") as fichier:
    contenu = fichier.read()

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.12.0-cp39-cp39-win_amd64.whl (1.9 kB)
# Collecting tensorflow-intel==2.12.0
#   Downloading tensorflow_intel-2.12.0-cp39-cp39-win_amd64.whl (272.8 MB)
#      -------------------------------------- 272.8/272.8 MB 8.4 MB/s eta 0:00:00
# Collecting keras<2.13,>=2.12.0
#   Downloading keras-2.12.0-py2.py3-none-any.whl (1.7 MB)
#      ---------------------------------------- 1.7/1.7 MB 108.0 MB/s eta 0:00:00
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.31.0-cp39-cp39-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 47.6 MB/s eta 0:00:00
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.54.2-cp39-cp39-win_amd64.whl (4.1 MB)
#      ---------------------------------------- 4.1/4.1 MB 89.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\user\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.3.0)
# Collecting jax>=0.3.15
#   Downloading jax-0.4.10.tar.gz (1.3 MB)
#      ---------------------------------------- 1.3/1.3 MB 84.5 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting tensorflow-estimator<2.13,>=2.12.0
#   Downloading tensorflow_estimator-2.12.0-py2.py3-none-any.whl (440 kB)
#      ------------------------------------- 440.7/440.7 kB 26.9 MB/s eta 0:00:00
# Collecting flatbuffers>=2.0
#   Downloading flatbuffers-23.5.9-py2.py3-none-any.whl (26 kB)
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ---------------------------------------- 57.5/57.5 kB ? eta 0:00:00
# Collecting numpy<1.24,>=1.22
#   Downloading numpy-1.23.5-cp39-cp39-win_amd64.whl (14.7 MB)
#      --------------------------------------- 14.7/14.7 MB 59.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging in c:\users\user\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (21.3)
# Collecting absl-py>=1.0.0
#   Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ---------------------------------------- 65.5/65.5 kB 3.5 MB/s eta 0:00:00
# Collecting termcolor>=1.1.0
#   Downloading termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Collecting tensorboard<2.13,>=2.12
#   Downloading tensorboard-2.12.3-py3-none-any.whl (5.6 MB)
#      ---------------------------------------- 5.6/5.6 MB 59.9 MB/s eta 0:00:00
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3
#   Downloading protobuf-4.23.1-cp39-cp39-win_amd64.whl (422 kB)
#      ---------------------------------------- 422.5/422.5 kB ? eta 0:00:00
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (63.4.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\user\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.14.1)
# Collecting libclang>=13.0.0
#   Downloading libclang-16.0.0-py2.py3-none-win_amd64.whl (24.4 MB)
#      --------------------------------------- 24.4/24.4 MB 50.4 MB/s eta 0:00:00
# Requirement already satisfied: h5py>=2.9.0 in c:\users\user\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.7.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\user\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.16.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\user\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow) (0.37.1)
# Collecting ml-dtypes>=0.1.0
#   Downloading ml_dtypes-0.1.0-cp39-cp39-win_amd64.whl (120 kB)
#      -------------------------------------- 120.3/120.3 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.7 in c:\users\user\anaconda3\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (1.9.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\user\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.3.4)
# Collecting google-auth<3,>=1.6.3
#   Using cached google_auth-2.18.1-py2.py3-none-any.whl (178 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\user\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.28.1)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Using cached tensorboard_data_server-0.7.0-py3-none-any.whl (2.4 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.0.3)
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Using cached google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\user\anaconda3\lib\site-packages (from packaging->tensorflow-intel==2.12.0->tensorflow) (3.0.9)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Requirement already satisfied: urllib3<2.0 in c:\users\user\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.26.11)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\user\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.2.8)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.3.0-py3-none-any.whl (9.3 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2022.9.14)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\user\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.4.8)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Building wheels for collected packages: jax
#   Building wheel for jax (pyproject.toml): started
#   Building wheel for jax (pyproject.toml): finished with status 'done'
#   Created wheel for jax: filename=jax-0.4.10-py3-none-any.whl size=1480617 sha256=c65ee2798113f34622d633b3841d4b604310ad4847eb23028db647d1bd61fc25
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\e5\6c\70\7c6be85fa56f05480fe043bdf0d4f6ec316b122be21e098066
# Successfully built jax
# Installing collected packages: libclang, flatbuffers, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, rsa, protobuf, oauthlib, numpy, keras, grpcio, google-pasta, gast, cachetools, astunparse, absl-py, requests-oauthlib, opt-einsum, ml-dtypes, google-auth, jax, google-auth-oauthlib, tensorboard, tensorflow-intel, tensorflow
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.5
#     Uninstalling numpy-1.21.5:
#       Successfully uninstalled numpy-1.21.5
# Successfully installed absl-py-1.4.0 astunparse-1.6.3 cachetools-5.3.0 flatbuffers-23.5.9 gast-0.4.0 google-auth-2.18.1 google-auth-oauthlib-1.0.0 google-pasta-0.2.0 grpcio-1.54.2 jax-0.4.10 keras-2.12.0 libclang-16.0.0 ml-dtypes-0.1.0 numpy-1.23.5 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-4.23.1 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.12.3 tensorboard-data-server-0.7.0 tensorflow-2.12.0 tensorflow-estimator-2.12.0 tensorflow-intel-2.12.0 tensorflow-io-gcs-filesystem-0.31.0 termcolor-2.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.6.0 requires daal==2021.4.0, which is not installed.
# numba 0.55.1 requires numpy<1.22,>=1.18, but you have numpy 1.23.5 which is incompatible.

# %%
# Import series of helper functions for our notebook
from helper_functions import create_tensorboard_callback, plot_loss_curves, unzip_data, compare_historys, walk_through_dir, pred_and_plot, load_and_prep_image

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# %%
# Let's check birds datasets
tfds.list_builders()

# %% [markdown]
# We have two datasets available in TensorFlow Datasets:
# * caltech_birds2010
# * caltech_birds2011
#
# If I check those on the tensorflow's website: https://www.tensorflow.org/datasets/catalog/caltech_birds2011?hl=fr we have the following description:
# * Caltech-UCSD Birds 200 (CUB-200) is an image dataset with photos of 200 bird species (mostly North American). The total number of categories of birds is 200 and there are 6033 images in the 2010 dataset and 11,788 images in the 2011 dataset. Annotations include bounding boxes, segmentation labels.
#
# We can see on the 2011 dataset, the number of images is twice as big as the 2010 one's. Because the bigger the sample is the higher the accuracy is, I will choose the second one `caltech_birds2011`.
#
# Now, it is time to get our data in train and test set and see what they look like.

# %%
# # Load train and test data.
# (test_data, train_data), ds_info = tfds.load(name="caltech_birds2011",
#                                     split=["test", "train"], # from the tensorflow's website, we can see there are only sets (train and test) with respectively 5794 and 5994 images.
#                                     shuffle_files=True,
#                                     as_supervised=True, # Because I work with labels
#                                     with_info=True) # I want to see what my data look like

# %%
# # Let's look at the features from the caltech_birds2011 dataset
# ds_info.features

# %% [markdown]
# ## Dataset from kaggle

# %% [markdown]
# Unfortunatelly this dataset doesn't seem to let me to get labels, so I will use another set that I have on my drive.
#
# On this dataset I have 510 breeds of birds.

# %%
# Create train and test dir
train_dir = "../Google Drive/Mon Drive/Birds/train"
test_dir = "../Google Drive/Mon Drive/Birds/test"

# %%
import tensorflow as tf
import random
import os

# %%
# Prepare databatch of 32 images for the training model
IMG_SIZE = (224, 224)
train_data = tf.keras.preprocessing.image_dataset_from_directory(train_dir,
                                                                 label_mode="categorical",
                                                                 image_size=IMG_SIZE)

test_data = tf.keras.preprocessing.image_dataset_from_directory(test_dir,
                                                                label_mode="categorical",
                                                                image_size=IMG_SIZE,
                                                                shuffle=False)
# Out:
# Found 80677 files belonging to 510 classes.
# Found 2539 files belonging to 510 classes.

# %% [markdown]
# There are 80677 images to train our model.
# There are 2539  images to test our model.

# %% [markdown]
# ## Exploring our data

# %%
# Create the list of class
class_names = train_data.class_names
class_names[:10]
# Out:
# ['ABBOTTS BABBLER',
#  'ABBOTTS BOOBY',
#  'ABYSSINIAN GROUND HORNBILL',
#  'AFRICAN CROWNED CRANE',
#  'AFRICAN EMERALD CUCKOO',
#  'AFRICAN FIREFINCH',
#  'AFRICAN OYSTER CATCHER',
#  'AFRICAN PIED HORNBILL',
#  'AFRICAN PYGMY GOOSE',
#  'ALBATROSS']

# %%
# Let's see a sample of 6 images
plt.figure(figsize=(10, 5))
for i in range(6): 
  # Choose a random image from a random class
  class_name = random.choice(class_names) 
  filename = random.choice(os.listdir(train_dir + "/" + class_name))
  filepath = train_dir + "/" + class_name + "/" + filename

  # Load the image and make predictions
  img = load_and_prep_image(filepath, scale=False)

  # plot the images
  plt.subplot(2, 3, i+1)
  plt.imshow(img/255.)
  plt.title(class_name)
  plt.axis(False);

# %%
# What is the shape of our data ?
train_data
# Out:
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 510), dtype=tf.float32, name=None))>

# %% [markdown]
# We have a batch of 32 images of shape (224, 224, 3) and labels of 510 classes

# %% [markdown]
# ## Create model callbacks

# %%
# Create ModelCheckpoint callback to save model's progress
checkpoint_path = "/content/drive/MyDrive/Birds/checkpoint/cp.ckpt" # saving weights requires ".ckpt" extension
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(checkpoint_path,
                                                      monitor="val_accuracy", # save the model weights with best validation accuracy
                                                      save_best_only=True, # only save the best weights
                                                      save_weights_only=True, # only save model weights (not whole model)
                                                      verbose=0) # don't print out whether or not model is being saved

# %% [markdown]
# ## Create data augmentation layer

# %%
# Create a data augmentation layer to incorporate it right into the model
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras import Sequential

# Setup data augmentation
data_augmentation = Sequential([
    preprocessing.RandomFlip("horizontal"),
    preprocessing.RandomRotation(0.2),
    preprocessing.RandomHeight(0.2),
    preprocessing.RandomWidth(0.2),
    preprocessing.RandomZoom(0.2),
    # preprocessing.Rescale(1/255.) # Resnet50
],name="data_augmentation")

# %% [markdown]
# ## Build a feature extraction model

# %% [markdown]
# To build the feature extraction model we will use transfer learning with architecture `EfficientNetB0`: https://www.tensorflow.org/api_docs/python/tf/keras/applications/efficientnet/EfficientNetB0

# %%
# Setup the base model and freeze its layers (this will extract features)
base_model = tf.keras.applications.EfficientNetB0(include_top=False)
base_model.trainable = False

# Setup model architecture with trainable top layers
inputs = layers.Input(shape=(224, 224, 3), name="input_layer")
x = data_augmentation(inputs)
x = base_model(x, training=False) # Put the base model in inference mode so weights need to stay frozen
x = layers.GlobalAveragePooling2D(name="global_avg_pool_layer")(x)
outputs = layers.Dense(len(class_names), activation="softmax", name="output_layer")(x)
model_1 = tf.keras.Model(inputs, outputs)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 1s 0us/step

# %%
# Get a summary of model we've created
model_1.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 224, 224, 3)]     0
#
#  data_augmentation (Sequenti  (None, None, None, 3)    0
#  al)
#
#  efficientnetb0 (Functional)  (None, None, None, 1280)  4049571
#
#  global_avg_pool_layer (Glob  (None, 1280)             0
#  alAveragePooling2D)
#
#  output_layer (Dense)        (None, 510)               653310
#
# =================================================================
# Total params: 4,702,881
# Trainable params: 653,310
# Non-trainable params: 4,049,571
# _________________________________________________________________

# %%
# Compile the model
model_1.compile(loss="categorical_crossentropy", 
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

# %%
# Fit the model and save its history
history_1_extractor = model_1.fit(train_data,
                      epochs=3,
                      steps_per_epoch=len(train_data),
                      validation_data=test_data,
                      validation_steps=int(0.05 * len(test_data)),
                      callbacks=[model_checkpoint])
# Out:
# Epoch 1/3
# 2522/2522 [==============================] - 2773s 1s/step - loss: 1.4036 - accuracy: 0.7420 - val_loss: 0.5244 - val_accuracy: 0.8906
# Epoch 2/3
# 2522/2522 [==============================] - 1285s 509ms/step - loss: 0.5079 - accuracy: 0.8811 - val_loss: 0.3199 - val_accuracy: 0.9219
# Epoch 3/3
# 2522/2522 [==============================] - 1321s 524ms/step - loss: 0.3830 - accuracy: 0.9059 - val_loss: 0.2589 - val_accuracy: 0.9062

# %%
# Evaluate on the whole test dataset
feature_extraction_results = model_1.evaluate(test_data)
feature_extraction_results
# Out:
# 80/80 [==============================] - 84s 1s/step - loss: 0.1605 - accuracy: 0.9626
# [0.16045084595680237, 0.9625837206840515]

# %%
# Plot the loss and accuracy for training and testing
plot_loss_curves(history_1_extractor)

# %% [markdown]
# ## Fine-tuning

# %%
# Unfreeze all of the layers in the base model
base_model.trainable = True

# Refreeze every layers except the last 5
for layer in base_model.layers[:-5]:
  layer.trainable=False

# %%
# Recompile (we have to recompile our models every time we make a change)
model_1.compile(loss="categorical_crossentropy",
                optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), # learning rate dictate how much your model patterns should update to try improve the loss functions
                metrics=["accuracy"])

# %%
initial_epoch = 3

# %%
# Continue to train and fit the model to our data  
fine_tune_epochs = initial_epoch + 3
history_1_fine = model_1.fit(train_data,
                                      epochs=fine_tune_epochs,
                                      validation_data=test_data,
                                      validation_steps=int(0.05 * len(test_data)),
                                      initial_epoch=history_1_extractor.epoch[-1], 
                                      callbacks=[create_tensorboard_callback(dir_name="drive/MyDrive/Birds/transfer_learning", 
                                                                             experiment_name="Birds")])
# Out:
# Saving TensorBoard log files to: drive/MyDrive/Birds/transfer_learning/Birds/20230520-220132
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring... Unable to serialize [2.0896919 2.1128857 2.1081853] to JSON. Unrecognized type <class 'tensorflow.python.framework.ops.EagerTensor'>.
# Epoch 3/6
# 2522/2522 [==============================] - 1418s 561ms/step - loss: 0.2550 - accuracy: 0.9331 - val_loss: 0.2087 - val_accuracy: 0.9141
# Epoch 4/6
# 2522/2522 [==============================] - 1504s 596ms/step - loss: 0.2083 - accuracy: 0.9438 - val_loss: 0.1989 - val_accuracy: 0.9219
# Epoch 5/6
# 2522/2522 [==============================] - 1599s 634ms/step - loss: 0.1844 - accuracy: 0.9495 - val_loss: 0.1551 - val_accuracy: 0.9375
# Epoch 6/6
# 2522/2522 [==============================] - 1424s 564ms/step - loss: 0.1632 - accuracy: 0.9557 - val_loss: 0.1597 - val_accuracy: 0.9375

# %%
# Evaluate on the whole test dataset
fine_tuning_results = model_1.evaluate(test_data)
fine_tuning_results
# Out:
# 80/80 [==============================] - 39s 486ms/step - loss: 0.1096 - accuracy: 0.9646
# [0.10963425040245056, 0.9645529985427856]

# %%
# Compare the histories of feature extration and fine tuning
compare_historys(history_1_extractor,
                 history_1_fine,
                 initial_epoch)

# %% [markdown]
# ## Making predictions with our trained model

# %%
# Calculate the probabilities of the predictions
preds_probs = model_1.predict(test_data, verbose=1)
# Out:
# 80/80 [==============================] - 36s 442ms/step

# %%
# Get the pred classes of each labels
pred_classes = preds_probs.argmax(axis=1)

# How do they look ?
pred_classes[:10]
# Out:
# array([  0,   0,   0,   0,   0,   1,   1,   1, 336,   1], dtype=int64)

# %%
# To get our test labels we need to unravel our test_data BatchDataseta
y_labels = []
for image, label in test_data.unbatch():
    y_labels.append(label.numpy().argmax())

# %% [markdown]
# ## Evaluate our predictions by plotting F1-scores histogramme of the differents classes

# %%
# Plot the classification report
from sklearn.metrics import classification_report
print(classification_report(y_true=y_labels,
                            y_pred=pred_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         5
#            1       1.00      0.80      0.89         5
#            2       1.00      1.00      1.00         5
#            3       1.00      1.00      1.00         5
#            4       1.00      1.00      1.00         5
#            5       1.00      0.80      0.89         5
#            6       1.00      1.00      1.00         5
#            7       1.00      0.80      0.89         5
#            8       1.00      1.00      1.00         5
#            9       1.00      1.00      1.00         5
#           10       1.00      1.00      1.00         5
#           11       1.00      1.00      1.00         5
#           12       0.83      1.00      0.91         5
#           13       1.00      0.80      0.89         5
#           14       1.00      1.00      1.00         5
#           15       1.00      1.00      1.00         5
#           16       1.00      1.00      1.00         5
{'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '26': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '27': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '28': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '29': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '30': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '31': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '32': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '33': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '34': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '35': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '36': {'precision': 1.0,
#   'recall': 0.4,
#   'f1-score': 0.5714285714285715,
#   'support': 5},
#  '37': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '38': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '39': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '40': {'precision': 0.7142857142857143,
#   'recall': 1.0,
#   'f1-score': 0.8333333333333333,
#   'support': 5},
#  '41': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '42': {'precision': 0.8,
#   'recall': 0.8,
#   'f1-score': 0.8000000000000002,
#   'support': 5},
#  '43': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '44': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '45': {'precision': 0.7142857142857143,
#   'recall': 1.0,
#   'f1-score': 0.8333333333333333,
#   'support': 5},
#  '46': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '47': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '48': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '49': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '50': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '51': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '52': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '53': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '54': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '55': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '56': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '57': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '58': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '59': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '60': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '61': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '62': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '63': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '64': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '65': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '66': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '67': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '68': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '69': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '70': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '71': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '72': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '73': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '74': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '75': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '76': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '77': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '78': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '79': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '80': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '81': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '82': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '83': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '84': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '85': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '86': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '87': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '88': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '89': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '90': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '91': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '92': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '93': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '94': {'precision': 0.7142857142857143,
#   'recall': 1.0,
#   'f1-score': 0.8333333333333333,
#   'support': 5},
#  '95': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '96': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '97': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '98': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '99': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '100': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '101': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '102': {'precision': 1.0,
#   'recall': 0.6,
#   'f1-score': 0.7499999999999999,
#   'support': 5},
#  '103': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '104': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '105': {'precision': 1.0,
#   'recall': 0.4,
#   'f1-score': 0.5714285714285715,
#   'support': 5},
#  '106': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '107': {'precision': 1.0,
#   'recall': 0.6,
#   'f1-score': 0.7499999999999999,
#   'support': 5},
#  '108': {'precision': 0.625,
#   'recall': 1.0,
#   'f1-score': 0.7692307692307693,
#   'support': 5},
#  '109': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '110': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '111': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '112': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '113': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '114': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '115': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '116': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '117': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '118': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '119': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '120': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '121': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '122': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '123': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '124': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '125': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '126': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '127': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '128': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '129': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '130': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '131': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '132': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '133': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '134': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '135': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '136': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '137': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '138': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '139': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '140': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '141': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '142': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '143': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '144': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '145': {'precision': 0.5555555555555556,
#   'recall': 1.0,
#   'f1-score': 0.7142857142857143,
#   'support': 5},
#  '146': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '147': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '148': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '149': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '150': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '151': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '152': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '153': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '154': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '155': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '156': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '157': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '158': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '159': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '160': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '161': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '162': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '163': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '164': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '165': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '166': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '167': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '168': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '169': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '170': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '171': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '172': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '173': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '174': {'precision': 0.7142857142857143,
#   'recall': 1.0,
#   'f1-score': 0.8333333333333333,
#   'support': 5},
#  '175': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '176': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '177': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '178': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '179': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '180': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '181': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '182': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '183': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '184': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '185': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '186': {'precision': 1.0,
#   'recall': 0.6,
#   'f1-score': 0.7499999999999999,
#   'support': 5},
#  '187': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '188': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '189': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '190': {'precision': 0.5714285714285714,
#   'recall': 0.8,
#   'f1-score': 0.6666666666666666,
#   'support': 5},
#  '191': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '192': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '193': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '194': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '195': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '196': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '197': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '198': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '199': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '200': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '201': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '202': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '203': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '204': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '205': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '206': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '207': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '208': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '209': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '210': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '211': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '212': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '213': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '214': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '215': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '216': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '217': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '218': {'precision': 0.7142857142857143,
#   'recall': 1.0,
#   'f1-score': 0.8333333333333333,
#   'support': 5},
#  '219': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '220': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '221': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '222': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '223': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '224': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '225': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '226': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '227': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '228': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '229': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '230': {'precision': 1.0,
#   'recall': 0.4,
#   'f1-score': 0.5714285714285715,
#   'support': 5},
#  '231': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '232': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '233': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '234': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '235': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '236': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '237': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '238': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '239': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '240': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '241': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '242': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '243': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '244': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '245': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '246': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '247': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '248': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '249': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '250': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '251': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '252': {'precision': 1.0,
#   'recall': 0.6,
#   'f1-score': 0.7499999999999999,
#   'support': 5},
#  '253': {'precision': 0.6666666666666666,
#   'recall': 0.8,
#   'f1-score': 0.7272727272727272,
#   'support': 5},
#  '254': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 4},
#  '257': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '258': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '259': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '260': {'precision': 0.8,
#   'recall': 0.8,
#   'f1-score': 0.8000000000000002,
#   'support': 5},
#  '261': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '262': {'precision': 0.7142857142857143,
#   'recall': 1.0,
#   'f1-score': 0.8333333333333333,
#   'support': 5},
#  '263': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '264': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '265': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '266': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '267': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '268': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '269': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '270': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '271': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '272': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '273': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '274': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '275': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '276': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '277': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '278': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '279': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '280': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '281': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '282': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '283': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '284': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '285': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '286': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '287': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '288': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '289': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '290': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '291': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '292': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '293': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '294': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '295': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '296': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '297': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '298': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '299': {'precision': 0.625,
#   'recall': 1.0,
#   'f1-score': 0.7692307692307693,
#   'support': 5},
#  '300': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '301': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '302': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '303': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '304': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '305': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '306': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '307': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '308': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '309': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '310': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '311': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '312': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '313': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '314': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '315': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '316': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '317': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '318': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '319': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '320': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '321': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '322': {'precision': 1.0,
#   'recall': 0.4,
#   'f1-score': 0.5714285714285715,
#   'support': 5},
#  '323': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '324': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '325': {'precision': 0.7142857142857143,
#   'recall': 1.0,
#   'f1-score': 0.8333333333333333,
#   'support': 5},
#  '326': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '327': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '328': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '329': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '330': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '331': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '332': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '333': {'precision': 0.7142857142857143,
#   'recall': 1.0,
#   'f1-score': 0.8333333333333333,
#   'support': 5},
#  '334': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '335': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '336': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '337': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '338': {'precision': 1.0,
#   'recall': 0.6,
#   'f1-score': 0.7499999999999999,
#   'support': 5},
#  '339': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '340': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '341': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '342': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '343': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '344': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '345': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '346': {'precision': 0.0, 'recall': 0.0, 'f1-score': 0.0, 'support': 5},
#  '347': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '348': {'precision': 0.625,
#   'recall': 1.0,
#   'f1-score': 0.7692307692307693,
#   'support': 5},
#  '349': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '350': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '351': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '352': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '353': {'precision': 1.0,
#   'recall': 0.6,
#   'f1-score': 0.7499999999999999,
#   'support': 5},
#  '354': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '355': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '356': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '357': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '358': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '359': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '360': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '361': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '362': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '363': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '364': {'precision': 0.7142857142857143,
#   'recall': 1.0,
#   'f1-score': 0.8333333333333333,
#   'support': 5},
#  '365': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '366': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '367': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '368': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '369': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '370': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '371': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '372': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '373': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '374': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '375': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '376': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '377': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '378': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '379': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '380': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '381': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '382': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '383': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '384': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '385': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '386': {'precision': 0.7142857142857143,
#   'recall': 1.0,
#   'f1-score': 0.8333333333333333,
#   'support': 5},
#  '387': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '388': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '389': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '390': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '391': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '392': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '393': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '394': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '395': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '396': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '397': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '398': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '399': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '400': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '401': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '402': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '403': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '404': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '405': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '406': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '407': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '408': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '409': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '410': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '411': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '412': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '413': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '414': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '415': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '416': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '417': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '418': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '419': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '420': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '421': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '422': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '423': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '424': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '425': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '426': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '427': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '428': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '429': {'precision': 1.0,
#   'recall': 0.4,
#   'f1-score': 0.5714285714285715,
#   'support': 5},
#  '430': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '431': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '432': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '433': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '434': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '435': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '436': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '437': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '438': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '439': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '440': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '441': {'precision': 1.0,
#   'recall': 0.6,
#   'f1-score': 0.7499999999999999,
#   'support': 5},
#  '442': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '443': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '444': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '445': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '446': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '447': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '448': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '449': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '450': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '451': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '452': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '453': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '454': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '455': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '456': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '457': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '458': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '459': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '460': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '461': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '462': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '463': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '464': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '465': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '466': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '467': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '468': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '469': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '470': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '471': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '472': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '473': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '474': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '475': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '476': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '477': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '478': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '479': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '480': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '481': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '482': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '483': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '484': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '485': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '486': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '487': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '488': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '489': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '490': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '491': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '492': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '493': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '494': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '495': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '496': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '497': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '498': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '499': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '500': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '501': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '502': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '503': {'precision': 1.0,
#   'recall': 0.6,
#   'f1-score': 0.7499999999999999,
#   'support': 5},
#  '504': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '505': {'precision': 0.8333333333333334,
#   'recall': 1.0,
#   'f1-score': 0.9090909090909091,
#   'support': 5},
#  '506': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '507': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  '508': {'precision': 1.0,
#   'recall': 0.8,
#   'f1-score': 0.888888888888889,
#   'support': 5},
#  '509': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 5},
#  'accuracy': 0.9645529736116581,
#  'macro avg': {'precision': 0.9707200662417198,
#   'recall': 0.9645669291338582,
#   'f1-score': 0.962781018194404,
#   'support': 2539},
#  'weighted avg': {'precision': 0.9707085341685577,
#   'recall': 0.9645529736116581,
#   'f1-score': 0.962766359280735,
#   'support': 2539}}

# %%
# Map classes to F1-scores
class_f1_scores = {}
# Loop through classification report dictionnary items
for k, v in classification_report_dict.items():
  if k == "accuracy": # stop once we get to accuracy key
    break
  else:
    # Add class names and f1-scores to new dictionnary
    class_f1_scores[class_names[int(k)]] = v["f1-score"]
class_f1_scores
# Out:
# {'ABBOTTS BABBLER': 1.0,
#  'ABBOTTS BOOBY': 0.888888888888889,
#  'ABYSSINIAN GROUND HORNBILL': 1.0,
#  'AFRICAN CROWNED CRANE': 1.0,
#  'AFRICAN EMERALD CUCKOO': 1.0,
#  'AFRICAN FIREFINCH': 0.888888888888889,
#  'AFRICAN OYSTER CATCHER': 1.0,
#  'AFRICAN PIED HORNBILL': 0.888888888888889,
#  'AFRICAN PYGMY GOOSE': 1.0,
#  'ALBATROSS': 1.0,
#  'ALBERTS TOWHEE': 1.0,
#  'ALEXANDRINE PARAKEET': 1.0,
#  'ALPINE CHOUGH': 0.9090909090909091,
#  'ALTAMIRA YELLOWTHROAT': 0.888888888888889,
#  'AMERICAN AVOCET': 1.0,
#  'AMERICAN BITTERN': 1.0,
#  'AMERICAN COOT': 1.0,
#  'AMERICAN FLAMINGO': 1.0,
#  'AMERICAN GOLDFINCH': 0.8333333333333333,
#  'AMERICAN KESTREL': 1.0,
#  'AMERICAN PIPIT': 1.0,
#  'AMERICAN REDSTART': 0.888888888888889,
#  'AMERICAN ROBIN': 1.0,
#  'AMERICAN WIGEON': 0.888888888888889,
#  'AMETHYST WOODSTAR': 0.7499999999999999,
#  'ANDEAN GOOSE': 1.0,
#  'ANDEAN LAPWING': 1.0,
#  'ANDEAN SISKIN': 0.888888888888889,
#  'ANHINGA': 1.0,
#  'ANIANIAU': 0.888888888888889,
#  'ANNAS HUMMINGBIRD': 1.0,
#  'ANTBIRD': 0.888888888888889,
#  'ANTILLEAN EUPHONIA': 1.0,
#  'APAPANE': 1.0,
#  'APOSTLEBIRD': 1.0,
#  'ARARIPE MANAKIN': 1.0,
#  'ASHY STORM PETREL': 0.5714285714285715,
#  'ASHY THRUSHBIRD': 1.0,
#  'ASIAN CRESTED IBIS': 1.0,
#  'ASIAN DOLLARD BIRD': 1.0,
#  'ASIAN GREEN BEE EATER': 0.8333333333333333,
#  'AUCKLAND SHAQ': 0.9090909090909091,
#  'AUSTRAL CANASTERO': 0.8000000000000002,
#  'AUSTRALASIAN FIGBIRD': 0.9090909090909091,
#  'AVADAVAT': 1.0,
#  'AZARAS SPINETAIL': 0.8333333333333333,
#  'AZURE BREASTED PITTA': 1.0,
#  'AZURE JAY': 1.0,
#  'AZURE TANAGER': 1.0,
#  'AZURE TIT': 1.0,
#  'BAIKAL TEAL': 1.0,
#  'BALD EAGLE': 1.0,
#  'BALD IBIS': 1.0,
#  'BALI STARLING': 1.0,
#  'BALTIMORE ORIOLE': 0.888888888888889,
#  'BANANAQUIT': 1.0,
#  'BAND TAILED GUAN': 1.0,
#  'BANDED BROADBILL': 1.0,
#  'BANDED PITA': 1.0,
#  'BANDED STILT': 1.0,
#  'BAR-TAILED GODWIT': 1.0,
#  'BARN OWL': 0.888888888888889,
#  'BARN SWALLOW': 1.0,
#  'BARRED PUFFBIRD': 0.888888888888889,
#  'BARROWS GOLDENEYE': 1.0,
#  'BAY-BREASTED WARBLER': 0.888888888888889,
#  'BEARDED BARBET': 1.0,
#  'BEARDED BELLBIRD': 1.0,
#  'BEARDED REEDLING': 1.0,
#  'BELTED KINGFISHER': 1.0,
#  'BIRD OF PARADISE': 1.0,
#  'BLACK AND YELLOW BROADBILL': 1.0,
#  'BLACK BAZA': 1.0,
#  'BLACK COCKATO': 0.9090909090909091,
#  'BLACK FACED SPOONBILL': 1.0,
#  'BLACK FRANCOLIN': 1.0,
#  'BLACK HEADED CAIQUE': 1.0,
#  'BLACK NECKED STILT': 1.0,
#  'BLACK SKIMMER': 0.888888888888889,
#  'BLACK SWAN': 1.0,
#  'BLACK TAIL CRAKE': 0.9090909090909091,
#  'BLACK THROATED BUSHTIT': 1.0,
#  'BLACK THROATED HUET': 1.0,
#  'BLACK THROATED WARBLER': 1.0,
#  'BLACK VENTED SHEARWATER': 0.888888888888889,
#  'BLACK VULTURE': 1.0,
#  'BLACK-CAPPED CHICKADEE': 1.0,
#  'BLACK-NECKED GREBE': 1.0,
#  'BLACK-THROATED SPARROW': 1.0,
#  'BLACKBURNIAM WARBLER': 0.888888888888889,
#  'BLONDE CRESTED WOODPECKER': 0.9090909090909091,
#  'BLOOD PHEASANT': 1.0,
#  'BLUE COAU': 0.888888888888889,
#  'BLUE DACNIS': 0.888888888888889,
#  'BLUE GRAY GNATCATCHER': 0.8333333333333333,
#  'BLUE GROSBEAK': 1.0,
#  'BLUE GROUSE': 1.0,
#  'BLUE HERON': 1.0,
#  'BLUE MALKOHA': 1.0,
#  'BLUE THROATED TOUCANET': 1.0,
#  'BOBOLINK': 1.0,
#  'BORNEAN BRISTLEHEAD': 1.0,
#  'BORNEAN LEAFBIRD': 0.7499999999999999,
#  'BORNEAN PHEASANT': 1.0,
#  'BRANDT CORMARANT': 0.9090909090909091,
#  'BREWERS BLACKBIRD': 0.5714285714285715,
#  'BROWN CREPPER': 1.0,
#  'BROWN HEADED COWBIRD': 0.7499999999999999,
#  'BROWN NOODY': 0.7692307692307693,
#  'BROWN THRASHER': 1.0,
#  'BUFFLEHEAD': 1.0,
#  'BULWERS PHEASANT': 1.0,
#  'BURCHELLS COURSER': 1.0,
#  'BUSH TURKEY': 1.0,
#  'CAATINGA CACHOLOTE': 1.0,
#  'CACTUS WREN': 0.888888888888889,
#  'CALIFORNIA CONDOR': 1.0,
#  'CALIFORNIA GULL': 0.9090909090909091,
#  'CALIFORNIA QUAIL': 1.0,
#  'CAMPO FLICKER': 1.0,
#  'CANARY': 1.0,
#  'CANVASBACK': 1.0,
#  'CAPE GLOSSY STARLING': 1.0,
#  'CAPE LONGCLAW': 1.0,
#  'CAPE MAY WARBLER': 0.9090909090909091,
#  'CAPE ROCK THRUSH': 1.0,
#  'CAPPED HERON': 1.0,
#  'CAPUCHINBIRD': 1.0,
#  'CARMINE BEE-EATER': 1.0,
#  'CASPIAN TERN': 1.0,
#  'CASSOWARY': 1.0,
#  'CEDAR WAXWING': 1.0,
#  'CERULEAN WARBLER': 1.0,
#  'CHARA DE COLLAR': 0.9090909090909091,
#  'CHATTERING LORY': 1.0,
#  'CHESTNET BELLIED EUPHONIA': 0.9090909090909091,
#  'CHINESE BAMBOO PARTRIDGE': 1.0,
#  'CHINESE POND HERON': 0.888888888888889,
#  'CHIPPING SPARROW': 1.0,
#  'CHUCAO TAPACULO': 1.0,
#  'CHUKAR PARTRIDGE': 1.0,
#  'CINNAMON ATTILA': 1.0,
#  'CINNAMON FLYCATCHER': 1.0,
#  'CINNAMON TEAL': 1.0,
#  'CLARKS GREBE': 1.0,
#  'CLARKS NUTCRACKER': 0.7142857142857143,
#  'COCK OF THE  ROCK': 1.0,
#  'COCKATOO': 1.0,
#  'COLLARED ARACARI': 1.0,
#  'COLLARED CRESCENTCHEST': 1.0,
#  'COMMON FIRECREST': 1.0,
#  'COMMON GRACKLE': 1.0,
#  'COMMON HOUSE MARTIN': 0.9090909090909091,
#  'COMMON IORA': 0.9090909090909091,
#  'COMMON LOON': 1.0,
#  'COMMON POORWILL': 0.888888888888889,
#  'COMMON STARLING': 1.0,
#  'COPPERSMITH BARBET': 0.888888888888889,
#  'COPPERY TAILED COUCAL': 0.9090909090909091,
#  'CRAB PLOVER': 1.0,
#  'CRANE HAWK': 1.0,
#  'CREAM COLORED WOODPECKER': 1.0,
#  'CRESTED AUKLET': 1.0,
#  'CRESTED CARACARA': 1.0,
#  'CRESTED COUA': 1.0,
#  'CRESTED FIREBACK': 1.0,
#  'CRESTED KINGFISHER': 1.0,
#  'CRESTED NUTHATCH': 1.0,
#  'CRESTED OROPENDOLA': 1.0,
#  'CRESTED SERPENT EAGLE': 0.888888888888889,
#  'CRESTED SHRIKETIT': 1.0,
#  'CRESTED WOOD PARTRIDGE': 1.0,
#  'CRIMSON CHAT': 1.0,
#  'CRIMSON SUNBIRD': 0.9090909090909091,
#  'CROW': 0.8333333333333333,
#  'CROWNED PIGEON': 0.9090909090909091,
#  'CUBAN TODY': 1.0,
#  'CUBAN TROGON': 1.0,
#  'CURL CRESTED ARACURI': 1.0,
#  'D-ARNAUDS BARBET': 1.0,
#  'DALMATIAN PELICAN': 1.0,
#  'DARJEELING WOODPECKER': 0.888888888888889,
#  'DARK EYED JUNCO': 1.0,
#  'DAURIAN REDSTART': 1.0,
#  'DEMOISELLE CRANE': 1.0,
#  'DOUBLE BARRED FINCH': 1.0,
#  'DOUBLE BRESTED CORMARANT': 0.7499999999999999,
#  'DOUBLE EYED FIG PARROT': 1.0,
#  'DOWNY WOODPECKER': 1.0,
#  'DUSKY LORY': 1.0,
#  'DUSKY ROBIN': 0.6666666666666666,
#  'EARED PITA': 1.0,
#  'EASTERN BLUEBIRD': 0.9090909090909091,
#  'EASTERN BLUEBONNET': 0.888888888888889,
#  'EASTERN GOLDEN WEAVER': 0.9090909090909091,
#  'EASTERN MEADOWLARK': 1.0,
#  'EASTERN ROSELLA': 1.0,
#  'EASTERN TOWEE': 1.0,
#  'EASTERN WIP POOR WILL': 0.9090909090909091,
#  'EASTERN YELLOW ROBIN': 0.9090909090909091,
#  'ECUADORIAN HILLSTAR': 1.0,
#  'EGYPTIAN GOOSE': 1.0,
#  'ELEGANT TROGON': 0.888888888888889,
#  'ELLIOTS  PHEASANT': 1.0,
#  'EMERALD TANAGER': 1.0,
#  'EMPEROR PENGUIN': 1.0,
#  'EMU': 1.0,
#  'ENGGANO MYNA': 1.0,
#  'EURASIAN BULLFINCH': 0.888888888888889,
#  'EURASIAN GOLDEN ORIOLE': 1.0,
#  'EURASIAN MAGPIE': 1.0,
#  'EUROPEAN GOLDFINCH': 1.0,
#  'EUROPEAN TURTLE DOVE': 1.0,
#  'EVENING GROSBEAK': 1.0,
#  'FAIRY BLUEBIRD': 1.0,
#  'FAIRY PENGUIN': 1.0,
#  'FAIRY TERN': 0.888888888888889,
#  'FAN TAILED WIDOW': 0.888888888888889,
#  'FASCIATED WREN': 0.8333333333333333,
#  'FIERY MINIVET': 1.0,
#  'FIORDLAND PENGUIN': 1.0,
#  'FIRE TAILLED MYZORNIS': 1.0,
#  'FLAME BOWERBIRD': 1.0,
#  'FLAME TANAGER': 1.0,
#  'FOREST WAGTAIL': 0.888888888888889,
#  'FRIGATE': 1.0,
#  'FRILL BACK PIGEON': 1.0,
#  'GAMBELS QUAIL': 1.0,
#  'GANG GANG COCKATOO': 1.0,
#  'GILA WOODPECKER': 0.888888888888889,
#  'GILDED FLICKER': 0.5714285714285715,
#  'GLOSSY IBIS': 1.0,
#  'GO AWAY BIRD': 1.0,
#  'GOLD WING WARBLER': 1.0,
#  'GOLDEN BOWER BIRD': 1.0,
#  'GOLDEN CHEEKED WARBLER': 1.0,
#  'GOLDEN CHLOROPHONIA': 1.0,
#  'GOLDEN EAGLE': 1.0,
#  'GOLDEN PARAKEET': 1.0,
#  'GOLDEN PHEASANT': 1.0,
#  'GOLDEN PIPIT': 1.0,
#  'GOULDIAN FINCH': 1.0,
#  'GRANDALA': 0.9090909090909091,
#  'GRAY CATBIRD': 1.0,
#  'GRAY KINGBIRD': 0.9090909090909091,
#  'GRAY PARTRIDGE': 1.0,
#  'GREAT ARGUS': 1.0,
#  'GREAT GRAY OWL': 1.0,
#  'GREAT JACAMAR': 1.0,
#  'GREAT KISKADEE': 1.0,
#  'GREAT POTOO': 1.0,
#  'GREAT TINAMOU': 1.0,
#  'GREAT XENOPS': 0.7499999999999999,
#  'GREATER PEWEE': 0.7272727272727272,
#  'GREATER PRAIRIE CHICKEN': 1.0,
#  'GREEN JAY': 1.0,
#  'GREEN MAGPIE': 1.0,
#  'GREEN WINGED DOVE': 1.0,
#  'GREY CUCKOOSHRIKE': 0.8000000000000002,
#  'GREY HEADED FISH EAGLE': 1.0,
#  'GREY PLOVER': 0.8333333333333333,
#  'GROVED BILLED ANI': 1.0,
#  'GUINEA TURACO': 0.9090909090909091,
#  'GUINEAFOWL': 1.0,
#  'GURNEYS PITTA': 1.0,
#  'GYRFALCON': 1.0,
#  'HAMERKOP': 1.0,
#  'HARLEQUIN DUCK': 1.0,
#  'HARLEQUIN QUAIL': 1.0,
#  'HARPY EAGLE': 1.0,
#  'HAWAIIAN GOOSE': 1.0,
#  'HAWFINCH': 1.0,
#  'HELMET VANGA': 1.0,
#  'HEPATIC TANAGER': 1.0,
#  'HIMALAYAN BLUETAIL': 1.0,
#  'HIMALAYAN MONAL': 1.0,
#  'HOATZIN': 1.0,
#  'HOODED MERGANSER': 1.0,
#  'HOOPOES': 1.0,
#  'HORNED GUAN': 1.0,
#  'HORNED LARK': 1.0,
#  'HORNED SUNGEM': 1.0,
#  'HOUSE FINCH': 1.0,
#  'HOUSE SPARROW': 0.9090909090909091,
#  'HYACINTH MACAW': 0.9090909090909091,
#  'IBERIAN MAGPIE': 1.0,
#  'IBISBILL': 1.0,
#  'IMPERIAL SHAQ': 1.0,
#  'INCA TERN': 1.0,
#  'INDIAN BUSTARD': 1.0,
#  'INDIAN PITTA': 1.0,
#  'INDIAN ROLLER': 1.0,
#  'INDIAN VULTURE': 1.0,
#  'INDIGO BUNTING': 0.9090909090909091,
#  'INDIGO FLYCATCHER': 0.9090909090909091,
#  'INLAND DOTTEREL': 1.0,
#  'IVORY BILLED ARACARI': 1.0,
#  'IVORY GULL': 0.7692307692307693,
#  'IWI': 1.0,
#  'JABIRU': 1.0,
#  'JACK SNIPE': 1.0,
#  'JACOBIN PIGEON': 1.0,
#  'JANDAYA PARAKEET': 1.0,
#  'JAPANESE ROBIN': 1.0,
#  'JAVA SPARROW': 1.0,
#  'JOCOTOCO ANTPITTA': 1.0,
#  'KAGU': 1.0,
#  'KAKAPO': 1.0,
#  'KILLDEAR': 1.0,
#  'KING EIDER': 1.0,
#  'KING VULTURE': 1.0,
#  'KIWI': 1.0,
#  'KOOKABURRA': 1.0,
#  'LARK BUNTING': 1.0,
#  'LAUGHING GULL': 0.888888888888889,
#  'LAZULI BUNTING': 1.0,
#  'LESSER ADJUTANT': 1.0,
#  'LILAC ROLLER': 1.0,
#  'LIMPKIN': 1.0,
#  'LITTLE AUK': 1.0,
#  'LOGGERHEAD SHRIKE': 0.5714285714285715,
#  'LONG-EARED OWL': 1.0,
#  'LOONEY BIRDS': 1.0,
#  'LUCIFER HUMMINGBIRD': 0.8333333333333333,
#  'MAGPIE GOOSE': 1.0,
#  'MALABAR HORNBILL': 0.9090909090909091,
#  'MALACHITE KINGFISHER': 0.888888888888889,
#  'MALAGASY WHITE EYE': 0.9090909090909091,
#  'MALEO': 1.0,
#  'MALLARD DUCK': 1.0,
#  'MANDRIN DUCK': 1.0,
#  'MANGROVE CUCKOO': 0.8333333333333333,
#  'MARABOU STORK': 1.0,
#  'MASKED BOBWHITE': 0.888888888888889,
#  'MASKED BOOBY': 0.9090909090909091,
#  'MASKED LAPWING': 1.0,
#  'MCKAYS BUNTING': 0.7499999999999999,
#  'MERLIN': 0.9090909090909091,
#  'MIKADO  PHEASANT': 1.0,
#  'MILITARY MACAW': 1.0,
#  'MOURNING DOVE': 1.0,
#  'MYNA': 1.0,
#  'NICOBAR PIGEON': 1.0,
#  'NOISY FRIARBIRD': 1.0,
#  'NORTHERN BEARDLESS TYRANNULET': 0.0,
#  'NORTHERN CARDINAL': 1.0,
#  'NORTHERN FLICKER': 0.7692307692307693,
#  'NORTHERN FULMAR': 1.0,
#  'NORTHERN GANNET': 1.0,
#  'NORTHERN GOSHAWK': 1.0,
#  'NORTHERN JACANA': 0.888888888888889,
#  'NORTHERN MOCKINGBIRD': 0.7499999999999999,
#  'NORTHERN PARULA': 1.0,
#  'NORTHERN RED BISHOP': 1.0,
#  'NORTHERN SHOVELER': 1.0,
#  'OCELLATED TURKEY': 1.0,
#  'OKINAWA RAIL': 1.0,
#  'ORANGE BRESTED BUNTING': 1.0,
#  'ORIENTAL BAY OWL': 1.0,
#  'ORNATE HAWK EAGLE': 1.0,
#  'OSPREY': 1.0,
#  'OSTRICH': 1.0,
#  'OVENBIRD': 0.8333333333333333,
#  'OYSTER CATCHER': 1.0,
#  'PAINTED BUNTING': 1.0,
#  'PALILA': 1.0,
#  'PALM NUT VULTURE': 1.0,
#  'PARADISE TANAGER': 1.0,
#  'PARAKETT  AKULET': 1.0,
#  'PARUS MAJOR': 1.0,
#  'PATAGONIAN SIERRA FINCH': 1.0,
#  'PEACOCK': 1.0,
#  'PEREGRINE FALCON': 1.0,
#  'PHAINOPEPLA': 0.9090909090909091,
#  'PHILIPPINE EAGLE': 1.0,
#  'PINK ROBIN': 1.0,
#  'PLUSH CRESTED JAY': 1.0,
#  'POMARINE JAEGER': 0.9090909090909091,
#  'PUFFIN': 1.0,
#  'PUNA TEAL': 1.0,
#  'PURPLE FINCH': 1.0,
#  'PURPLE GALLINULE': 1.0,
#  'PURPLE MARTIN': 1.0,
#  'PURPLE SWAMPHEN': 1.0,
#  'PYGMY KINGFISHER': 0.8333333333333333,
#  'PYRRHULOXIA': 0.888888888888889,
#  'QUETZAL': 1.0,
#  'RAINBOW LORIKEET': 1.0,
#  'RAZORBILL': 1.0,
#  'RED BEARDED BEE EATER': 1.0,
#  'RED BELLIED PITTA': 0.888888888888889,
#  'RED BILLED TROPICBIRD': 1.0,
#  'RED BROWED FINCH': 0.9090909090909091,
#  'RED FACED CORMORANT': 1.0,
#  'RED FACED WARBLER': 1.0,
#  'RED FODY': 1.0,
#  'RED HEADED DUCK': 1.0,
#  'RED HEADED WOODPECKER': 0.9090909090909091,
#  'RED KNOT': 1.0,
#  'RED LEGGED HONEYCREEPER': 1.0,
#  'RED NAPED TROGON': 0.9090909090909091,
#  'RED SHOULDERED HAWK': 0.888888888888889,
#  'RED TAILED HAWK': 0.9090909090909091,
#  'RED TAILED THRUSH': 1.0,
#  'RED WINGED BLACKBIRD': 1.0,
#  'RED WISKERED BULBUL': 1.0,
#  'REGENT BOWERBIRD': 1.0,
#  'RING-NECKED PHEASANT': 0.9090909090909091,
#  'ROADRUNNER': 1.0,
#  'ROCK DOVE': 1.0,
#  'ROSE BREASTED COCKATOO': 1.0,
#  'ROSE BREASTED GROSBEAK': 1.0,
#  'ROSEATE SPOONBILL': 1.0,
#  'ROSY FACED LOVEBIRD': 1.0,
#  'ROUGH LEG BUZZARD': 1.0,
#  'ROYAL FLYCATCHER': 1.0,
#  'RUBY CROWNED KINGLET': 0.888888888888889,
#  'RUBY THROATED HUMMINGBIRD': 1.0,
#  'RUDDY SHELDUCK': 1.0,
#  'RUDY KINGFISHER': 1.0,
#  'RUFOUS KINGFISHER': 0.888888888888889,
#  'RUFOUS TREPE': 1.0,
#  'RUFUOS MOTMOT': 1.0,
#  'SAMATRAN THRUSH': 0.888888888888889,
#  'SAND MARTIN': 1.0,
#  'SANDHILL CRANE': 1.0,
#  'SATYR TRAGOPAN': 1.0,
#  'SAYS PHOEBE': 0.5714285714285715,
#  'SCARLET CROWNED FRUIT DOVE': 1.0,
#  'SCARLET FACED LIOCICHLA': 1.0,
#  'SCARLET IBIS': 1.0,
#  'SCARLET MACAW': 1.0,
#  'SCARLET TANAGER': 1.0,
#  'SHOEBILL': 1.0,
#  'SHORT BILLED DOWITCHER': 1.0,
#  'SMITHS LONGSPUR': 0.9090909090909091,
#  'SNOW GOOSE': 1.0,
#  'SNOWY EGRET': 1.0,
#  'SNOWY OWL': 0.9090909090909091,
#  'SNOWY PLOVER': 0.7499999999999999,
#  'SORA': 1.0,
#  'SPANGLED COTINGA': 1.0,
#  'SPLENDID WREN': 0.9090909090909091,
#  'SPOON BILED SANDPIPER': 0.888888888888889,
#  'SPOTTED CATBIRD': 1.0,
#  'SPOTTED WHISTLING DUCK': 1.0,
#  'SQUACCO HERON': 0.9090909090909091,
#  'SRI LANKA BLUE MAGPIE': 1.0,
#  'STEAMER DUCK': 1.0,
#  'STORK BILLED KINGFISHER': 1.0,
#  'STRIATED CARACARA': 1.0,
#  'STRIPED OWL': 1.0,
#  'STRIPPED MANAKIN': 1.0,
#  'STRIPPED SWALLOW': 0.9090909090909091,
#  'SUNBITTERN': 1.0,
#  'SUPERB STARLING': 1.0,
#  'SURF SCOTER': 1.0,
#  'SWINHOES PHEASANT': 1.0,
#  'TAILORBIRD': 1.0,
#  'TAIWAN MAGPIE': 1.0,
#  'TAKAHE': 1.0,
#  'TASMANIAN HEN': 1.0,
#  'TAWNY FROGMOUTH': 1.0,
#  'TEAL DUCK': 0.9090909090909091,
#  'TIT MOUSE': 1.0,
#  'TOUCHAN': 1.0,
#  'TOWNSENDS WARBLER': 0.9090909090909091,
#  'TREE SWALLOW': 1.0,
#  'TRICOLORED BLACKBIRD': 1.0,
#  'TROPICAL KINGBIRD': 1.0,
#  'TRUMPTER SWAN': 1.0,
#  'TURKEY VULTURE': 1.0,
#  'TURQUOISE MOTMOT': 1.0,
#  'UMBRELLA BIRD': 0.888888888888889,
#  'VARIED THRUSH': 1.0,
#  'VEERY': 1.0,
#  'VENEZUELIAN TROUPIAL': 0.9090909090909091,
#  'VERDIN': 1.0,
#  'VERMILION FLYCATHER': 0.9090909090909091,
#  'VICTORIA CROWNED PIGEON': 0.888888888888889,
#  'VIOLET BACKED STARLING': 1.0,
#  'VIOLET GREEN SWALLOW': 1.0,
#  'VIOLET TURACO': 1.0,
#  'VISAYAN HORNBILL': 1.0,
#  'VULTURINE GUINEAFOWL': 1.0,
#  'WALL CREAPER': 1.0,
#  'WATTLED CURASSOW': 0.888888888888889,
#  'WATTLED LAPWING': 1.0,
#  'WHIMBREL': 1.0,
#  'WHITE BREASTED WATERHEN': 1.0,
#  'WHITE BROWED CRAKE': 1.0,
#  'WHITE CHEEKED TURACO': 0.888888888888889,
#  'WHITE CRESTED HORNBILL': 1.0,
#  'WHITE EARED HUMMINGBIRD': 1.0,
#  'WHITE NECKED RAVEN': 1.0,
#  'WHITE TAILED TROPIC': 1.0,
#  'WHITE THROATED BEE EATER': 1.0,
#  'WILD TURKEY': 1.0,
#  'WILLOW PTARMIGAN': 0.888888888888889,
#  'WILSONS BIRD OF PARADISE': 1.0,
#  'WOOD DUCK': 1.0,
#  'WOOD THRUSH': 0.7499999999999999,
#  'WOODLAND KINGFISHER': 1.0,
#  'WRENTIT': 0.9090909090909091,
#  'YELLOW BELLIED FLOWERPECKER': 1.0,
#  'YELLOW CACIQUE': 1.0,
#  'YELLOW HEADED BLACKBIRD': 0.888888888888889,
#  'ZEBRA DOVE': 1.0}

# %%
# Turns f1-scores dictionary into dataframe for visualization
import pandas as pd
f1_scores = pd.DataFrame({"class_names":list(class_f1_scores.keys()),
                         "f1-score": list(class_f1_scores.values())}).sort_values("f1-score", ascending=False)
f1_scores.head()
# Out:
#          class_names  f1-score
# 0    ABBOTTS BABBLER       1.0
# 306             KAGU       1.0
# 318          LIMPKIN       1.0
# 317     LILAC ROLLER       1.0
# 316  LESSER ADJUTANT       1.0

# %%
# Plot the F1-scores histogramme from the dataframe
fig, ax = plt.subplots(figsize=(10, 100))
scores = ax.barh(range(len(f1_scores)), f1_scores["f1-score"].values) 
ax.set_yticks(range(len(f1_scores)))
ax.set_yticklabels(f1_scores["class_names"])
ax.set_xlabel("F1-score")
ax.set_title("F1-scores for 101 Different Food Classes")
ax.invert_yaxis(); 
ax.bar_label(scores, fmt='%.2f')
ax.set_xlim()
# Out:
# (0.0, 1.05)

# %% [markdown]
# ## Check the numbers of each classes

# %%
# Create a list of classes and their numbers
classes = []
numbers = []
for classe in os.listdir(train_dir):
    classes.append(classe)
    numbers.append(len(os.listdir(train_dir + "/" + classe)))

# %%
# Make it a DataFrame 
birds_num = pd.DataFrame({"Classes":classes,
                 "Number":numbers}).sort_values(by="Number", ascending=False)
birds_num
# Out:
#                      Classes  Number
# 279             RUFOUS TREPE     274
# 252                 OVENBIRD     233
# 444              HOUSE FINCH     232
# 57     ASIAN GREEN BEE EATER     220
# 351        SWINHOES PHEASANT     217
# ..                       ...     ...
# 286        ROUGH LEG BUZZARD      96
# 364  SCARLET FACED LIOCICHLA      90
# 287      ROSY FACED LOVEBIRD      83
# 373     VENEZUELIAN TROUPIAL      82
# 249             MASKED BOOBY      61
#
# [510 rows x 2 columns]

# %%
# Check the number of with the fewer F1-scores
birds_num[birds_num["Classes"] == "NORTHERN BEARDLESS TYRANNULET"]
# Out:
#                            Classes  Number
# 499  NORTHERN BEARDLESS TYRANNULET     185

# %%
# Plot an histogramme of classes vs numbers
fig, ax = plt.subplots(figsize=(15,5))
ax.bar(birds_num["Classes"][:20],
       birds_num["Number"][:20])
plt.title('Distribution of Top 20 Labels in Image Dataset', fontsize=16)
plt.xlabel('Label', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=45);

# %% [markdown]
# ## Visualizing predictions on test images

# %%
# Make preds on a series of random images
plt.figure(figsize=(17, 15))
for i in range(9): 
  # Choose a random image from a random class
  class_name = random.choice(class_names) 
  filename = random.choice(os.listdir(test_dir + "/" + class_name))
  filepath = test_dir + "/" + class_name + "/" + filename

  # Load the image and make predictions
  img = load_and_prep_image(filepath, scale=False)
  pred_prob = model_1.predict(tf.expand_dims(img, axis=0)) # get prediction probabilities array
  pred_class = class_names[pred_prob.argmax()] # get highest prediction probility index and match it to class_names list

  # plot the images
  plt.subplot(3, 3, i+1)
  plt.imshow(img/255.)
  if class_name == pred_class: # if predicted class matches truth class, make test green
    title_color = "g"
  else:
    title_color = "r"
  plt.title(f"actual: {class_name}, \n pred: {pred_class}, \n prob: {pred_prob.max():.2f}", c=title_color)
  plt.axis(False);
# Out:
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step

# %% [markdown]
# ## Finding the most wrong predictions

# %% [markdown]
# To find out where our model is most wrong, let's write some code to find out the following:
#
# 1. Get all of the image file paths in the test dataset using list_files() method.
# 2. Create a Pandas DataFrame of the image filepaths, ground truth labels, predicted classes (from our model), max predictions probabilities, prediction class names, ground truth class names.
# 3. Use our DataFrame to find all the wrong predictions (where the ground thruth label doesn't match the prediction).
# 4. Sort the DataFrame based on wrong predictions (have the highest prediction probability predictions at the top).
# 5. Visualize the images with the highest prediction probabilities but have the wrong prediction.

# %%
# 1. Get all image filepath in test dataset
filepaths = []
for filepath in test_data.list_files("../Google Drive/Mon Drive/Birds/test/*/*", shuffle=False):
  filepaths.append(filepath.numpy())
filepaths[:5]
# Out:
# [b'..\\Google Drive\\Mon Drive\\Birds\\test\\ABBOTTS BABBLER\\1.jpg',
#  b'..\\Google Drive\\Mon Drive\\Birds\\test\\ABBOTTS BABBLER\\2.jpg',
#  b'..\\Google Drive\\Mon Drive\\Birds\\test\\ABBOTTS BABBLER\\3.jpg',
#  b'..\\Google Drive\\Mon Drive\\Birds\\test\\ABBOTTS BABBLER\\4.jpg',
#  b'..\\Google Drive\\Mon Drive\\Birds\\test\\ABBOTTS BABBLER\\5.jpg']

# %%
# 2. Create pandas dataframe of differents parameters for each of our test images.
preds_df = pd.DataFrame({"imagepath":filepaths,
                         "y_true":y_labels,
                         "y_pred":pred_classes,
                         "pred_conf":preds_probs.max(axis=1), 
                         "y_true_classname":[class_names[i] for i in y_labels],
                         "y_pred_classname":[class_names[i] for i in pred_classes]})    
preds_df
# Out:
#                                               imagepath  y_true  y_pred  \
# 0     b'..\\Google Drive\\Mon Drive\\Birds\\test\\AB...       0       0
# 1     b'..\\Google Drive\\Mon Drive\\Birds\\test\\AB...       0       0
# 2     b'..\\Google Drive\\Mon Drive\\Birds\\test\\AB...       0       0
# 3     b'..\\Google Drive\\Mon Drive\\Birds\\test\\AB...       0       0
# 4     b'..\\Google Drive\\Mon Drive\\Birds\\test\\AB...       0       0
# ...                                                 ...     ...     ...
# 2534  b'..\\Google Drive\\Mon Drive\\Birds\\test\\ZE...     509     509
# 2535  b'..\\Google Drive\\Mon Drive\\Birds\\test\\ZE...     509     509
# 2536  b'..\\Google Drive\\Mon Drive\\Birds\\test\\ZE...     509     509
# 2537  b'..\\Google Drive\\Mon Drive\\Birds\\test\\ZE...     509     509
# 2538  b'..\\Google Drive\\Mon Drive\\Birds\\test\\ZE...     509     509
#
#       pred_conf y_true_classname y_pred_classname
# 0      0.806661  ABBOTTS BABBLER  ABBOTTS BABBLER
# 1      0.979316  ABBOTTS BABBLER  ABBOTTS BABBLER
# 2      0.991017  ABBOTTS BABBLER  ABBOTTS BABBLER
# 3      0.671101  ABBOTTS BABBLER  ABBOTTS BABBLER
# 4      0.997703  ABBOTTS BABBLER  ABBOTTS BABBLER
# ...         ...              ...              ...
# 2534   0.999936       ZEBRA DOVE       ZEBRA DOVE
# 2535   0.998434       ZEBRA DOVE       ZEBRA DOVE
# 2536   0.999987       ZEBRA DOVE       ZEBRA DOVE
# 2537   0.996997       ZEBRA DOVE       ZEBRA DOVE
# 2538   0.999941       ZEBRA DOVE       ZEBRA DOVE
#
# [2539 rows x 6 columns]

# %%
# 3. Find the wrong predictions
preds_df_wrong = preds_df[preds_df["y_true"] != preds_df["y_pred"]]
len(preds_df_wrong)
# Out:
# 90

# %%
# Sort by the highest probabilites at the top
preds_100_wrong = preds_df_wrong.sort_values("pred_conf", ascending=False)
preds_100_wrong[:5]
# Out:
#                                               imagepath  y_true  y_pred  \
# 1753  b'..\\Google Drive\\Mon Drive\\Birds\\test\\NO...     352      80
# 181   b'..\\Google Drive\\Mon Drive\\Birds\\test\\AS...      36     108
# 2100  b'..\\Google Drive\\Mon Drive\\Birds\\test\\RU...     422     386
# 306   b'..\\Google Drive\\Mon Drive\\Birds\\test\\BA...      61     440
# 1683  b'..\\Google Drive\\Mon Drive\\Birds\\test\\MC...     338     437
#
#       pred_conf   y_true_classname  y_pred_classname
# 1753   0.994013    NORTHERN JACANA  BLACK TAIL CRAKE
# 181    0.974145  ASHY STORM PETREL       BROWN NOODY
# 2100   0.960009  RUFOUS KINGFISHER  PYGMY KINGFISHER
# 306    0.940185           BARN OWL         SNOWY OWL
# 1683   0.938494     MCKAYS BUNTING   SMITHS LONGSPUR

# %%
# Save the dataframe just in case
preds_100_wrong.to_csv("drive/MyDrive/Birds/preds_100_wrong")
preds_100_wrong = pd.read_csv("drive/MyDrive/Birds/preds_100_wrong")
preds_100_wrong[:5]

# %%
# Plots the 9th first wrong images preds
images_to_view = 9
start_index = 0
plt.figure(figsize=(15,15))
for i, row in enumerate(preds_100_wrong[start_index:start_index+images_to_view].itertuples()):
  plt.subplot(3, 3, i+1)
  img = load_and_prep_image(row[1], scale=False)
  _, _, _, _, pred_prob, y_true_classname, y_pred_classname = row # only interested in a few parameters of each row
  plt.imshow(img/255.)
  plt.title(f"actual:{y_true_classname}, \n pred:{y_pred_classname}, \n prob:{pred_prob:.2f}")
  plt.axis(False)

# %% [markdown]
# ## Test out the birds model on our own custom images

# %%
# Create custom dir
custom_dir = "../Google Drive/Mon Drive/Birds/custom"

# %%
# Plot the predictions on our own images
plt.figure(figsize=(17, 15))
i = 0
for image in os.listdir(custom_dir): 
  # Choose a random image from a random class
  filename = image 
  filepath = custom_dir + "/" + filename

  # Load the image and make predictions
  img = load_and_prep_image(filepath, scale=False)
  pred_prob = model_1.predict(tf.expand_dims(img, axis=0)) # get prediction probabilities array
  pred_class = class_names[pred_prob.argmax()] # get highest prediction probility index and match it to class_names list

  # plot the images
  plt.subplot(int(len(os.listdir(custom_dir))/3) + 1, 3, i+1)
  plt.imshow(img/255.)
  plt.title(f" pred: {pred_class}, \n prob: {pred_prob.max():.2f}")
  plt.axis(False);
  i = i + 1
# Out:
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
